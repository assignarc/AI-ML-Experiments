# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("car-mpg.csv")    

mpg = data.copy()

display("Info of the dataset:",mpg.info())
display("Head of the dataset:",mpg.head())
display("Tail of the dataset:",mpg.tail())
display("Shape of the dataset:",mpg.shape)
display("Description of the dataset:",mpg.describe(include='all').T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mpg       398 non-null    float64
#  1   cyl       398 non-null    int64
#  2   disp      398 non-null    float64
#  3   hp        398 non-null    object
#  4   wt        398 non-null    int64
#  5   acc       398 non-null    float64
#  6   yr        398 non-null    int64
#  7   origin    398 non-null    int64
#  8   car_type  398 non-null    int64
#  9   car_name  398 non-null    object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 31.2+ KB
# 'Info of the dataset:'
# None
# 'Head of the dataset:'
#     mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 0  18.0    8  307.0  130  3504  12.0  70       1         0
# 1  15.0    8  350.0  165  3693  11.5  70       1         0
# 2  18.0    8  318.0  150  3436  11.0  70       1         0
# ...

# %%
display(mpg['origin'].value_counts())
display(mpg['car_type'].value_counts())
display(mpg['car_name'].value_counts())
# Out:
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64
# car_type
# 1    211
# 0    187
# Name: count, dtype: int64
# car_name
# ford pinto             6
# toyota corolla         5
# amc matador            5
# ford maverick          5
# chevrolet chevette     4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: count, Length: 305, dtype: int64

# %%
mpg.isnull().sum()
# Out:
# mpg         0
# cyl         0
# disp        0
# hp          0
# wt          0
# acc         0
# yr          0
# origin      0
# car_type    0
# car_name    0
# dtype: int64

# %%
mpg = mpg.drop('car_name',axis=1)
mpg['origin'] = mpg['origin'].replace({1: 'america', 2: 'europe', 3: 'asia'})
mpg = pd.get_dummies(mpg, columns=['origin'])
mpg = mpg.replace('?', np.nan)

# %%
display(mpg.describe().T)
# Out:
#           count         mean         std     min       25%     50%       75%  \
# mpg       398.0    23.514573    7.815984     9.0    17.500    23.0    29.000
# cyl       398.0     5.454774    1.701004     3.0     4.000     4.0     8.000
# disp      398.0   193.425879  104.269838    68.0   104.250   148.5   262.000
# wt        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5  3608.000
# acc       398.0    15.568090    2.757689     8.0    13.825    15.5    17.175
# yr        398.0    76.010050    3.697627    70.0    73.000    76.0    79.000
# car_type  398.0     0.530151    0.499718     0.0     0.000     1.0     1.000
#
#              max
# mpg         46.6
# cyl          8.0
# disp       455.0
# wt        5140.0
# acc         24.8
# yr          82.0
# car_type     1.0

# %%
X = mpg.drop('mpg', axis=1)
y = mpg['mpg']

import sklearn.preprocessing as preprocessing

X_Scaled = pd.DataFrame(preprocessing.scale(X))

# %%
display(X.head())
display(X_Scaled.head())
# Out:
#    cyl   disp   hp    wt   acc  yr  car_type  origin_america  origin_asia  \
# 0    8  307.0  130  3504  12.0  70         0            True        False
# 1    8  350.0  165  3693  11.5  70         0            True        False
# 2    8  318.0  150  3436  11.0  70         0            True        False
# 3    8  304.0  150  3433  12.0  70         0            True        False
# 4    8  302.0  140  3449  10.5  70         0            True        False
#
#    origin_europe
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#           0         1         2         3         4         5         6  \
# 0  1.498191  1.090604  0.664133  0.630870 -1.295498 -1.627426 -1.062235
# 1  1.498191  1.503514  1.574594  0.854333 -1.477038 -1.627426 -1.062235
# 2  1.498191  1.196232  1.184397  0.550470 -1.658577 -1.627426 -1.062235
# 3  1.498191  1.061796  1.184397  0.546923 -1.295498 -1.627426 -1.062235
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_Scaled, y, test_size=0.2, random_state=42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (318, 10) (80, 10) (318,) (80,)
