# %% [markdown]
# <center><font size=6>LLMs and Prompt Engineering</center></font>

# %% [markdown]
# <center><font size=6>Restaurant Review Analysis</center></font>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Business Context

# %% [markdown]
# In the food industry, customer satisfaction plays a pivotal role in shaping the success of individual outlets and the overall brand. A leading global food aggregator is keen on understanding and improving customer experiences across the diverse range of restaurants it lists on its platform. The company recognizes the significance of customer reviews in gaining insights into service quality, food offerings, and overall satisfaction.

# %% [markdown]
# ### Problem Definition

# %% [markdown]
# Despite the abundance of customer reviews available, the company faces significant challenges in deriving actionable insights from these valuable data sources. The manual analysis of extensive amounts of unstructured text data tends to be time-consuming and non-scalable. The key problems to address include:
#
# - **Unstructured Data Challenge**: Customer reviews are expressed in natural language and an unstructured format, creating difficulties in efficiently extracting meaningful information.
#
# - **Scale of Data**: With numerous restaurants, the company accumulates a substantial volume of reviews. Manually processing this vast amount of data is not scalable and necessitates an automated approach.
#
# - **Customer Sentiment Understanding**: Discerning customer sentiments from reviews, whether positive, negative, or neutral, poses a significant challenge. This understanding is crucial for the company to identify the preferences of different customers and devise strategies for targeted marketing.

# %% [markdown]
# ### Objective

# %% [markdown]
# As a data scientist at the company, you have been provided a sample of the customer review data and asked to created a predictive model to analyze the reviews. The objective is to build a robust sentiment analyzer using a Large Language Model (LLM) that accurately predicts the sentiment of customers from the reviews, thereby enhancing the company's ability to understand customer sentiments at scale, enabling data-driven decision-making, and improving overall customer satisfaction.

# %% [markdown]
# ## Installing and Importing Necessary Libraries

# %%
# Installation for GPU llama-cpp-python
# DO NOT RUN THESE COMMANDS IF YOU ARE USING LOCAL MACHINE, THESE WILL RESET THOSE FOR X86_64, and YOU WILL NOT BE ABLE TO RUN IT ON YOUR LOCAL MACHINE. 
# USE THE LAST COMMAND IF YOU ARE USING LOCAL APPLE SILICON MAC.

# uncomment and run the following code in case GPU is being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python==0.2.45 --force-reinstall --no-cache-dir -q

# Installation for CPU llama-cpp-python
# uncomment and run the following code in case GPU is not being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=off" FORCE_CMAKE=1 pip install llama-cpp-python==0.2.45 --force-reinstall --no-cache-dir -q

#Use this command command for Mac (Apple Silicon)
# !CMAKE_ARGS="-DGGML_METAL=on" FORCE_CMAKE=1 pip install llama-cpp-python # --no-cache-dir --force-reinstall # Uncomment if you want a fresh resinstall.
# Out:
# Requirement already satisfied: llama-cpp-python in /Users/vishalkhapre/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages (0.3.16)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/vishalkhapre/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages (from llama-cpp-python) (4.15.0)
# Requirement already satisfied: numpy>=1.20.0 in /Users/vishalkhapre/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages (from llama-cpp-python) (2.4.2)
# Requirement already satisfied: diskcache>=5.6.1 in /Users/vishalkhapre/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages (from llama-cpp-python) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in /Users/vishalkhapre/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages (from llama-cpp-python) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishalkhapre/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.3)

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# For downloading the models from HF Hub
# !pip install huggingface_hub==0.20.3 pandas==2.2.2 -q

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# Importing library for data manipulation
import pandas as pd

# Function to download the model from the Hugging Face model hub
from huggingface_hub import hf_hub_download

# Importing the Llama class from the llama_cpp module
from llama_cpp import Llama

# Importing the json module
import json

# %% [markdown]
# ## Import the dataset

# %%
# uncomment and run the below code snippets if the dataset is present in the Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
data = pd.read_csv("restaurant_reviews.csv")

# %% [markdown]
# ## Data Overview

# %%
# checking the first five rows of the data
data.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full
# 0  Totally in love with the Auro of the place, re...
# 1  Kailash colony is brimming with small cafes no...
# 2  Excellent taste and awesome decorum. Must visi...
# 3  I have visited at jw lough/restourant. There w...
# 4  Had a great experience in the restaurant food ...

# %%
# checking the shape of the data
data.shape
# Out:
# (20, 3)

# %% [markdown]
# **Observations**
#
# - Data has 20 rows and 3 columns

# %%
# checking for missing values
data.isnull().sum()
# Out:
# restaurant_ID    0
# rating_review    0
# review_full      0
# dtype: int64

# %% [markdown]
# **Observations**
#
# - There are no missing values in the data

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Loading the model (Llama)

# %%
model_name_or_path = "TheBloke/Llama-2-13B-chat-GGUF"
model_basename = "llama-2-13b-chat.Q5_K_M.gguf" # the model is in gguf format

# %%
# Using hf_hub_download to download a model from the Hugging Face model hub
# The repo_id parameter specifies the model name or path in the Hugging Face repository
# The filename parameter specifies the name of the file to download
model_path = hf_hub_download(
    repo_id=model_name_or_path,
    filename=model_basename
)

# %%
lcpp_llm = Llama(
    model_path=model_path,
    n_threads=4,  # CPU cores
    n_batch=512,  # Should be between 1 and n_ctx, consider the amount of VRAM in your GPU.
    n_gpu_layers=-1, # 25,  # uncomment and change this value based on GPU VRAM pool.
    n_ctx=4096,  # Context window
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M3 Pro) - 28747 MiB free
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from /Users/vishalkhapre/.cache/huggingface/hub/models--TheBloke--Llama-2-13B-chat-GGUF/snapshots/4458acc949de0a9914c3eab623904d4fe999050a/llama-2-13b-chat.Q5_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                          general.file_type u32              = 17
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q5_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# print_info: file format = GGUF V2
# print_info: file type   = Q5_K - Medium
# print_info: file size   = 8.60 GiB (5.67 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      1 '<s>' is not marked as EOG
# load: control token:      2 '</s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: printing all EOG tokens:
# load:   - 2 ('</s>')
# load: special tokens cache size = 3
# load: token to piece cache size = 0.1684 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 4096
# print_info: n_embd           = 5120
# print_info: n_layer          = 40
# print_info: n_head           = 40
# print_info: n_head_kv        = 40
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: is_swa_any       = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 1
# print_info: n_embd_k_gqa     = 5120
# print_info: n_embd_v_gqa     = 5120
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-05
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: f_attn_scale     = 0.0e+00
# print_info: n_ff             = 13824
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 10000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 4096
# print_info: rope_finetuned   = unknown
# print_info: model type       = 13B
# print_info: model params     = 13.02 B
# print_info: general.name     = LLaMA v2
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32000
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: loading model tensors, this can take a while... (mmap = true)
# load_tensors: layer   0 assigned to device Metal, is_swa = 0
# load_tensors: layer   1 assigned to device Metal, is_swa = 0
# load_tensors: layer   2 assigned to device Metal, is_swa = 0
# load_tensors: layer   3 assigned to device Metal, is_swa = 0
# load_tensors: layer   4 assigned to device Metal, is_swa = 0
# load_tensors: layer   5 assigned to device Metal, is_swa = 0
# load_tensors: layer   6 assigned to device Metal, is_swa = 0
# load_tensors: layer   7 assigned to device Metal, is_swa = 0
# load_tensors: layer   8 assigned to device Metal, is_swa = 0
# load_tensors: layer   9 assigned to device Metal, is_swa = 0
# load_tensors: layer  10 assigned to device Metal, is_swa = 0
# load_tensors: layer  11 assigned to device Metal, is_swa = 0
# load_tensors: layer  12 assigned to device Metal, is_swa = 0
# load_tensors: layer  13 assigned to device Metal, is_swa = 0
# load_tensors: layer  14 assigned to device Metal, is_swa = 0
# load_tensors: layer  15 assigned to device Metal, is_swa = 0
# load_tensors: layer  16 assigned to device Metal, is_swa = 0
# load_tensors: layer  17 assigned to device Metal, is_swa = 0
# load_tensors: layer  18 assigned to device Metal, is_swa = 0
# load_tensors: layer  19 assigned to device Metal, is_swa = 0
# load_tensors: layer  20 assigned to device Metal, is_swa = 0
# load_tensors: layer  21 assigned to device Metal, is_swa = 0
# load_tensors: layer  22 assigned to device Metal, is_swa = 0
# load_tensors: layer  23 assigned to device Metal, is_swa = 0
# load_tensors: layer  24 assigned to device Metal, is_swa = 0
# load_tensors: layer  25 assigned to device Metal, is_swa = 0
# load_tensors: layer  26 assigned to device Metal, is_swa = 0
# load_tensors: layer  27 assigned to device Metal, is_swa = 0
# load_tensors: layer  28 assigned to device Metal, is_swa = 0
# load_tensors: layer  29 assigned to device Metal, is_swa = 0
# load_tensors: layer  30 assigned to device Metal, is_swa = 0
# load_tensors: layer  31 assigned to device Metal, is_swa = 0
# load_tensors: layer  32 assigned to device Metal, is_swa = 0
# load_tensors: layer  33 assigned to device Metal, is_swa = 0
# load_tensors: layer  34 assigned to device Metal, is_swa = 0
# load_tensors: layer  35 assigned to device Metal, is_swa = 0
# load_tensors: layer  36 assigned to device Metal, is_swa = 0
# load_tensors: layer  37 assigned to device Metal, is_swa = 0
# load_tensors: layer  38 assigned to device Metal, is_swa = 0
# load_tensors: layer  39 assigned to device Metal, is_swa = 0
# load_tensors: layer  40 assigned to device Metal, is_swa = 0
# load_tensors: tensor 'token_embd.weight' (q5_K) (and 0 others) cannot be used with preferred buffer type CPU_REPACK, using CPU instead
# ggml_backend_metal_log_allocated_size: allocated buffer, size =  8694.22 MiB, ( 8700.17 / 28753.92)
# load_tensors: offloading 40 repeating layers to GPU
# load_tensors: offloading output layer to GPU
# load_tensors: offloaded 41/41 layers to GPU
# load_tensors: Metal_Mapped model buffer size =  8694.22 MiB
# load_tensors:   CPU_Mapped model buffer size =   107.42 MiB
# ...................................................................................................
# llama_context: constructing llama_context
# llama_context: n_seq_max     = 1
# llama_context: n_ctx         = 4096
# llama_context: n_ctx_per_seq = 4096
# llama_context: n_batch       = 512
# llama_context: n_ubatch      = 512
# llama_context: causal_attn   = 1
# llama_context: flash_attn    = 0
# llama_context: kv_unified    = false
# llama_context: freq_base     = 10000.0
# llama_context: freq_scale    = 1
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M3 Pro
# ggml_metal_init: picking default device: Apple M3 Pro
# ggml_metal_init: GPU name:   Apple M3 Pro
# ggml_metal_init: GPU family: MTLGPUFamilyApple9  (1009)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal4  (5002)
# ggml_metal_init: simdgroup reduction   = true
# ggml_metal_init: simdgroup matrix mul. = true
# ggml_metal_init: has residency sets    = true
# ggml_metal_init: has bfloat            = true
# ggml_metal_init: use bfloat            = false
# ggml_metal_init: hasUnifiedMemory      = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 30150.67 MB
# ggml_metal_init: loaded kernel_add                                    0x882e69800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_2                             0x882e69b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_3                             0x882e69e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_4                             0x882e6a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_5                             0x882e6a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_6                             0x882e6a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_7                             0x882e6aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_8                             0x882e6ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4                             0x882e6b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_2                      0x882e6b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_3                      0x882e6b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_4                      0x882e6b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_5                      0x882e6bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_6                      0x882fe4000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_7                      0x882fe4300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_8                      0x882fe4600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub                                    0x882fe4900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub_row_c4                             0x882fe4c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                                    0x882fe4f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row_c4                             0x882fe5200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div                                    0x882fe5500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div_row_c4                             0x882fe5800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_id                                 0x882fe5b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f32                             0x882fe5e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f16                             0x882fe6100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i32                             0x882fe6400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i16                             0x882fe6700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                                  0x882fe6a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale_4                                0x882fe6d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_clamp                                  0x882fe7000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_tanh                                   0x882fe7300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                                   0x882fe7600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sigmoid                                0x882fe7900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                                   0x882fe7c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_4                                 0x882fe8000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_erf                               0x882fe8300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_erf_4                             0x882fe8600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick                             0x882fe8900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick_4                           0x882fe8c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                                   0x882fe8f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu_4                                 0x882fe9200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_elu                                    0x882fe9500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_abs                                    0x882fe9800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sgn                                    0x882fe9b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_step                                   0x882fe9e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_hardswish                              0x882fea100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_hardsigmoid                            0x882fea400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_exp                                    0x882fea700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16                           0x882feaa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16_4                         0x882fead00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32                           0x882feb000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32_4                         0x882feb300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                          0x882feb600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                        0x882feb900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                           0x882febc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                           0x882fec000 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_get_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_get_rows_q4_0                          0x882fec300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                          0x882fec600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_0                          0x882fec900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_1                          0x882fecc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                          0x882fecf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_mxfp4                         0x882fed200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                          0x882fed500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                          0x882fed800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                          0x882fedb00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                          0x882fede00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                          0x882fee100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xxs                       0x882fee400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xs                        0x882fee700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_xxs                       0x882feea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_s                         0x882feed00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_s                         0x882fef000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_s                         0x882fef300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_m                         0x882fef600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_nl                        0x882fef900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_xs                        0x882fefc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_i32                           0x881578000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_f32                           0x881578300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_f16                           0x881578600 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_set_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_set_rows_q8_0                          0x881578900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q4_0                          0x881578c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q4_1                          0x881578f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q5_0                          0x881579200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q5_1                          0x881579500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_iq4_nl                        0x881579800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                               0x881579b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm_mul                           0x881579e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm_mul_add                       0x88157a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_l2_norm                                0x88157a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_group_norm                             0x88157a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                                   0x88157aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_conv_f32                           0x88157ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32                           0x88157b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32_group                     0x88157b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rwkv_wkv6_f32                          0x88157b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rwkv_wkv7_f32                          0x88157b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32                         0x88157bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32_c4                      0x882ff8000 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_c4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_1row              (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_l4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_bf16                  (not supported)
# ggml_metal_init: loaded kernel_mul_mv_f16_f32                         0x882ff8300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_c4                      0x882ff8600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_1row                    0x882ff8900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_l4                      0x882ff8c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f16                         0x882ff8f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_0_f32                        0x882ff9200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_1_f32                        0x882ff9500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_0_f32                        0x882ff9800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_1_f32                        0x882ff9b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q8_0_f32                        0x882ff9e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_mxfp4_f32                       0x882ffa100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_2                0x882ffa400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_3                0x882ffa700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_4                0x882ffaa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_5                0x882ffad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_2               0x882ffb000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_3               0x882ffb300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_4               0x882ffb600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_5               0x882ffb900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_2               0x882ffbc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_3               0x882ffc000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_4               0x882ffc300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_5               0x882ffc600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_2               0x882ffc900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_3               0x882ffcc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_4               0x882ffcf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_5               0x882ffd200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_2               0x882ffd500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_3               0x882ffd800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_4               0x882ffdb00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_5               0x882ffde00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_2               0x882ffe100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_3               0x882ffe400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_4               0x882ffe700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_5               0x882ffea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_2              0x882ffed00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_3              0x882fff000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_4              0x882fff300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_5              0x882fff600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_2               0x882fff900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_3               0x882fffc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_4               0x883000000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_5               0x883000300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_2               0x883000600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_3               0x883000900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_4               0x883000c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_5               0x883000f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_2               0x883001200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_3               0x883001500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_4               0x883001800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_5               0x883001b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_2             0x883001e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_3             0x883002100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_4             0x883002400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_5             0x883002700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q2_K_f32                        0x883002a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q3_K_f32                        0x883002d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_K_f32                        0x883003000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_K_f32                        0x883003300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q6_K_f32                        0x883003600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xxs_f32                     0x883003900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xs_f32                      0x883003c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_xxs_f32                     0x883004000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_s_f32                       0x883004300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_s_f32                       0x883004600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_s_f32                       0x883004900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_m_f32                       0x883004c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_nl_f32                      0x883004f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_xs_f32                      0x883005200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f32_f32                      0x883005500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f16_f32                      0x883005800 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mv_id_q4_0_f32                     0x883005b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_1_f32                     0x883005e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_0_f32                     0x883006100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_1_f32                     0x883006400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q8_0_f32                     0x883006700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_mxfp4_f32                    0x883006a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q2_K_f32                     0x883006d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q3_K_f32                     0x883007000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_K_f32                     0x883007300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_K_f32                     0x883007600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q6_K_f32                     0x883007900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xxs_f32                  0x883007c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xs_f32                   0x883008000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_xxs_f32                  0x883008300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_s_f32                    0x883008600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_s_f32                    0x883008900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_s_f32                    0x883008c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_m_f32                    0x883008f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_nl_f32                   0x883009200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_xs_f32                   0x883009500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f32_f32                         0x883009800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                         0x883009b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_bf16_f32                   (not supported)
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                        0x883009e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                        0x88300a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_0_f32                        0x88300a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_1_f32                        0x88300a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q8_0_f32                        0x88300aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_mxfp4_f32                       0x88300ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_mxfp4_f32                       0x88300b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                        0x88300b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                        0x88300b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                        0x88300b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                        0x88300bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                        0x883010000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xxs_f32                     0x883010300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xs_f32                      0x883010600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_xxs_f32                     0x883010900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_s_f32                       0x883010c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_s_f32                       0x883010f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_s_f32                       0x883011200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_m_f32                       0x883011500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_nl_f32                      0x883011800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_xs_f32                      0x883011b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_map0_f16                     0x883011e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_map1_f32                     0x883012100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f32_f16                      0x883012400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f16_f16                      0x883012700 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_id_bf16_f16                (not supported)
# ggml_metal_init: loaded kernel_mul_mm_id_q4_0_f16                     0x883012a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_1_f16                     0x883012d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_0_f16                     0x883013000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_1_f16                     0x883013300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q8_0_f16                     0x883013600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_mxfp4_f16                    0x883013900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q2_K_f16                     0x883013c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q3_K_f16                     0x883014000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_K_f16                     0x883014300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_K_f16                     0x883014600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q6_K_f16                     0x883014900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xxs_f16                  0x883014c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xs_f16                   0x883014f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_xxs_f16                  0x883015200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_s_f16                    0x883015500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_s_f16                    0x883015800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_s_f16                    0x883015b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_m_f16                    0x883015e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_nl_f16                   0x883016100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_xs_f16                   0x883016400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f32                          0x883016700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f16                          0x883016a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_multi_f32                         0x883016d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_multi_f16                         0x883017000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_vision_f32                        0x883017300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_vision_f16                        0x883017600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f32                          0x883017900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f16                          0x883017c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f16                             0x883018000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f32                             0x883018300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f16                         0x883018600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f32                         0x883018900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f32_f32              0x883018c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f16_f32              0x883018f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_upscale_f32                            0x883019200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_f32                                0x883019500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_reflect_1d_f32                     0x883019800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_timestep_embedding_f32                 0x883019b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_arange_f32                             0x883019e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_asc                    0x88301a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_desc                   0x88301a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_leaky_relu_f32                         0x88301a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h64                 0x88301aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h80                 0x88301ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h96                 0x88301b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h112                0x88301b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h128                0x88301b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h192                0x88301b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_hk192_hv128         0x88301bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h256                0x883020000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_hk576_hv512         0x883020300 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h192          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_hk192_hv128   (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h256          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_hk576_hv512   (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h64                0x883020600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h80                0x883020900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h96                0x883020c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h112               0x883020f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h128               0x883021200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h192               0x883021500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_hk192_hv128        0x883021800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h256               0x883021b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_hk576_hv512        0x883021e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h64                0x883022100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h80                0x883022400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h96                0x883022700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h112               0x883022a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h128               0x883022d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h192               0x883023000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_hk192_hv128        0x883023300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h256               0x883023600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_hk576_hv512        0x883023900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h64                0x883023c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h80                0x883024000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h96                0x883024300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h112               0x883024600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h128               0x883024900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h192               0x883024c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_hk192_hv128        0x883024f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h256               0x883025200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_hk576_hv512        0x883025500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h64                0x883025800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h80                0x883025b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h96                0x883025e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h112               0x883026100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h128               0x883026400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h192               0x883026700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_hk192_hv128        0x883026a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h256               0x883026d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_hk576_hv512        0x883027000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h64                0x883027300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h80                0x883027600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h96                0x883027900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h112               0x883027c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h128               0x88302c000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h192               0x88302c300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_hk192_hv128        0x88302c600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h256               0x88302c900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_hk576_hv512        0x88302cc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h64             0x88302cf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h64       (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h64            0x88302d200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h64            0x88302d500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h64            0x88302d800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h64            0x88302db00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h64            0x88302de00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h96             0x88302e100 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h96       (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h96            0x88302e400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h96            0x88302e700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h96            0x88302ea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h96            0x88302ed00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h96            0x88302f000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128            0x88302f300 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128           0x88302f600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128           0x88302f900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128           0x88302fc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128           0x883030000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128           0x883030300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h192            0x883030600 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h192      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h192           0x883030900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h192           0x883030c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h192           0x883030f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h192           0x883031200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h192           0x883031500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_hk192_hv128      0x883031800 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_hk192_hv128 (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_hk192_hv128      0x883031b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_hk192_hv128      0x883031e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_hk192_hv128      0x883032100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_hk192_hv128      0x883032400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_hk192_hv128      0x883032700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256            0x883032a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256           0x883032d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256           0x883033000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256           0x883033300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256           0x883033600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256           0x883033900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_hk576_hv512      0x883033c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_hk576_hv512 (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_hk576_hv512      0x883034000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_hk576_hv512      0x883034300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_hk576_hv512      0x883034600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_hk576_hv512      0x883034900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_hk576_hv512      0x883034c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                                0x883034f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                                0x883035200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                            0x883035500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                            0x883035800 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                            0x883035b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                            0x883035e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                           0x883036100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                           0x883036400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                           0x883036700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                           0x883036a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                           0x883036d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                         0x883037000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f32                           0x883037300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f16                           0x883037600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f32                           0x883037900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f16                           0x883037c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f32                           0x883038000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f16                           0x883038300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f32                           0x883038600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f16                           0x883038900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f32                           0x883038c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f16                           0x883038f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                                 0x883039200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                    0x883039500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                   0x883039800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                    0x883039b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                    0x883039e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_neg                                    0x88303a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_reglu                                  0x88303a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_geglu                                  0x88303a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_swiglu                                 0x88303aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_swiglu_oai                             0x88303ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_geglu_erf                              0x88303b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_geglu_quick                            0x88303b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                               0x88303b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mean                                   0x88303b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                                 0x88303bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                        0x88303c000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                        0x88303c300 | th_max = 1024 | th_width =   32
# set_abort_callback: call
# llama_context:        CPU  output buffer size =     0.12 MiB
# create_memory: n_ctx = 4096 (padded)
# llama_kv_cache_unified: layer   0: dev = Metal
# llama_kv_cache_unified: layer   1: dev = Metal
# llama_kv_cache_unified: layer   2: dev = Metal
# llama_kv_cache_unified: layer   3: dev = Metal
# llama_kv_cache_unified: layer   4: dev = Metal
# llama_kv_cache_unified: layer   5: dev = Metal
# llama_kv_cache_unified: layer   6: dev = Metal
# llama_kv_cache_unified: layer   7: dev = Metal
# llama_kv_cache_unified: layer   8: dev = Metal
# llama_kv_cache_unified: layer   9: dev = Metal
# llama_kv_cache_unified: layer  10: dev = Metal
# llama_kv_cache_unified: layer  11: dev = Metal
# llama_kv_cache_unified: layer  12: dev = Metal
# llama_kv_cache_unified: layer  13: dev = Metal
# llama_kv_cache_unified: layer  14: dev = Metal
# llama_kv_cache_unified: layer  15: dev = Metal
# llama_kv_cache_unified: layer  16: dev = Metal
# llama_kv_cache_unified: layer  17: dev = Metal
# llama_kv_cache_unified: layer  18: dev = Metal
# llama_kv_cache_unified: layer  19: dev = Metal
# llama_kv_cache_unified: layer  20: dev = Metal
# llama_kv_cache_unified: layer  21: dev = Metal
# llama_kv_cache_unified: layer  22: dev = Metal
# llama_kv_cache_unified: layer  23: dev = Metal
# llama_kv_cache_unified: layer  24: dev = Metal
# llama_kv_cache_unified: layer  25: dev = Metal
# llama_kv_cache_unified: layer  26: dev = Metal
# llama_kv_cache_unified: layer  27: dev = Metal
# llama_kv_cache_unified: layer  28: dev = Metal
# llama_kv_cache_unified: layer  29: dev = Metal
# llama_kv_cache_unified: layer  30: dev = Metal
# llama_kv_cache_unified: layer  31: dev = Metal
# llama_kv_cache_unified: layer  32: dev = Metal
# llama_kv_cache_unified: layer  33: dev = Metal
# llama_kv_cache_unified: layer  34: dev = Metal
# llama_kv_cache_unified: layer  35: dev = Metal
# llama_kv_cache_unified: layer  36: dev = Metal
# llama_kv_cache_unified: layer  37: dev = Metal
# llama_kv_cache_unified: layer  38: dev = Metal
# llama_kv_cache_unified: layer  39: dev = Metal
# llama_kv_cache_unified:      Metal KV buffer size =  3200.00 MiB
# llama_kv_cache_unified: size = 3200.00 MiB (  4096 cells,  40 layers,  1/1 seqs), K (f16): 1600.00 MiB, V (f16): 1600.00 MiB
# llama_context: enumerating backends
# llama_context: backend_ptrs.size() = 3
# llama_context: max_nodes = 2904
# llama_context: worst-case: n_tokens = 512, n_seqs = 1, n_outputs = 0
# graph_reserve: reserving a graph for ubatch with n_tokens =  512, n_seqs =  1, n_outputs =  512
# graph_reserve: reserving a graph for ubatch with n_tokens =    1, n_seqs =  1, n_outputs =    1
# graph_reserve: reserving a graph for ubatch with n_tokens =  512, n_seqs =  1, n_outputs =  512
# llama_context:      Metal compute buffer size =   388.01 MiB
# llama_context:        CPU compute buffer size =    38.01 MiB
# llama_context: graph nodes  = 1406
# llama_context: graph splits = 2
# Metal : EMBED_LIBRARY = 1 | CPU : NEON = 1 | ARM_FMA = 1 | FP16_VA = 1 | DOTPROD = 1 | LLAMAFILE = 1 | ACCELERATE = 1 | OPENMP = 1 | REPACK = 1 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '40', 'llama.context_length': '4096', 'llama.attention.head_count': '40', 'llama.rope.dimension_count': '128', 'general.file_type': '17', 'llama.feed_forward_length': '13824', 'llama.embedding_length': '5120', 'llama.block_count': '40', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'general.name': 'LLaMA v2'}
# Using fallback chat format: llama-2
# ggml_metal_free: deallocating
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)
# ggml_metal_mem_pool_free: freeing memory pool, num heaps = 0 (total = 0)

# %% [markdown]
# ### Loading the model (Mistral)

# %%
model_name_or_path = "TheBloke/Mistral-7B-Instruct-v0.2-GGUF"
model_basename = "mistral-7b-instruct-v0.2.Q6_K.gguf"

# %%
model_path = hf_hub_download(
    repo_id=model_name_or_path,
    filename=model_basename
)

# %%
llm = Llama(
    model_path=model_path,
    n_ctx=1024,
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M3 Pro) - 16465 MiB free
# llama_model_loader: loaded meta data with 24 key-value pairs and 291 tensors from /Users/vishalkhapre/.cache/huggingface/hub/models--TheBloke--Mistral-7B-Instruct-v0.2-GGUF/snapshots/3a6fbf4a41a1d52e415a4958cde6856d34b2db93/mistral-7b-instruct-v0.2.Q6_K.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = mistralai_mistral-7b-instruct-v0.2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 1000000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 18
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  19:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  20:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  21:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  22:                    tokenizer.chat_template str              = {{ bos_token }}{% for message in mess...
# llama_model_loader: - kv  23:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q6_K:  226 tensors
# print_info: file format = GGUF V3 (latest)
# print_info: file type   = Q6_K
# print_info: file size   = 5.53 GiB (6.56 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      2 '</s>' is not marked as EOG
# load: control token:      1 '<s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: printing all EOG tokens:
# load:   - 2 ('</s>')
# load: special tokens cache size = 3
# load: token to piece cache size = 0.1637 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 32768
# print_info: n_embd           = 4096
# print_info: n_layer          = 32
# print_info: n_head           = 32
# print_info: n_head_kv        = 8
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: is_swa_any       = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 4
# print_info: n_embd_k_gqa     = 1024
# print_info: n_embd_v_gqa     = 1024
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-05
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: f_attn_scale     = 0.0e+00
# print_info: n_ff             = 14336
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 1000000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 32768
# print_info: rope_finetuned   = unknown
# print_info: model type       = 7B
# print_info: model params     = 7.24 B
# print_info: general.name     = mistralai_mistral-7b-instruct-v0.2
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32000
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: PAD token        = 0 '<unk>'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: loading model tensors, this can take a while... (mmap = true)
# load_tensors: layer   0 assigned to device CPU, is_swa = 0
# load_tensors: layer   1 assigned to device CPU, is_swa = 0
# load_tensors: layer   2 assigned to device CPU, is_swa = 0
# load_tensors: layer   3 assigned to device CPU, is_swa = 0
# load_tensors: layer   4 assigned to device CPU, is_swa = 0
# load_tensors: layer   5 assigned to device CPU, is_swa = 0
# load_tensors: layer   6 assigned to device CPU, is_swa = 0
# load_tensors: layer   7 assigned to device CPU, is_swa = 0
# load_tensors: layer   8 assigned to device CPU, is_swa = 0
# load_tensors: layer   9 assigned to device CPU, is_swa = 0
# load_tensors: layer  10 assigned to device CPU, is_swa = 0
# load_tensors: layer  11 assigned to device CPU, is_swa = 0
# load_tensors: layer  12 assigned to device CPU, is_swa = 0
# load_tensors: layer  13 assigned to device CPU, is_swa = 0
# load_tensors: layer  14 assigned to device CPU, is_swa = 0
# load_tensors: layer  15 assigned to device CPU, is_swa = 0
# load_tensors: layer  16 assigned to device CPU, is_swa = 0
# load_tensors: layer  17 assigned to device CPU, is_swa = 0
# load_tensors: layer  18 assigned to device CPU, is_swa = 0
# load_tensors: layer  19 assigned to device CPU, is_swa = 0
# load_tensors: layer  20 assigned to device CPU, is_swa = 0
# load_tensors: layer  21 assigned to device CPU, is_swa = 0
# load_tensors: layer  22 assigned to device CPU, is_swa = 0
# load_tensors: layer  23 assigned to device CPU, is_swa = 0
# load_tensors: layer  24 assigned to device CPU, is_swa = 0
# load_tensors: layer  25 assigned to device CPU, is_swa = 0
# load_tensors: layer  26 assigned to device CPU, is_swa = 0
# load_tensors: layer  27 assigned to device CPU, is_swa = 0
# load_tensors: layer  28 assigned to device CPU, is_swa = 0
# load_tensors: layer  29 assigned to device CPU, is_swa = 0
# load_tensors: layer  30 assigned to device CPU, is_swa = 0
# load_tensors: layer  31 assigned to device CPU, is_swa = 0
# load_tensors: layer  32 assigned to device CPU, is_swa = 0
# load_tensors: tensor 'token_embd.weight' (q6_K) (and 290 others) cannot be used with preferred buffer type CPU_REPACK, using CPU instead
# load_tensors: offloading 0 repeating layers to GPU
# load_tensors: offloaded 0/33 layers to GPU
# load_tensors:   CPU_Mapped model buffer size =  5666.09 MiB
# ...................................................................................................
# llama_context: constructing llama_context
# llama_context: n_seq_max     = 1
# llama_context: n_ctx         = 1024
# llama_context: n_ctx_per_seq = 1024
# llama_context: n_batch       = 512
# llama_context: n_ubatch      = 512
# llama_context: causal_attn   = 1
# llama_context: flash_attn    = 0
# llama_context: kv_unified    = false
# llama_context: freq_base     = 1000000.0
# llama_context: freq_scale    = 1
# llama_context: n_ctx_per_seq (1024) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M3 Pro
# ggml_metal_init: picking default device: Apple M3 Pro
# ggml_metal_init: GPU name:   Apple M3 Pro
# ggml_metal_init: GPU family: MTLGPUFamilyApple9  (1009)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal4  (5002)
# ggml_metal_init: simdgroup reduction   = true
# ggml_metal_init: simdgroup matrix mul. = true
# ggml_metal_init: has residency sets    = true
# ggml_metal_init: has bfloat            = true
# ggml_metal_init: use bfloat            = false
# ggml_metal_init: hasUnifiedMemory      = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 30150.67 MB
# ggml_metal_init: loaded kernel_add                                    0x88303f900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_2                             0x88303f600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_3                             0x88303f300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_4                             0x88303f000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_5                             0x88303ed00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_6                             0x88303ea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_7                             0x88303e700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_fuse_8                             0x88303e400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4                             0x88303e100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_2                      0x88303de00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_3                      0x88303db00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_4                      0x88303d800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_5                      0x88303d500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_6                      0x88303d200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_7                      0x88303cf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row_c4_fuse_8                      0x88303cc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub                                    0x88303c900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub_row_c4                             0x88303c600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                                    0x88303fc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row_c4                             0x882e68f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div                                    0x882e69500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div_row_c4                             0x882e69200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_id                                 0x882e68c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f32                             0x882e68900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f16                             0x882e68600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i32                             0x882e68300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i16                             0x882e68000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                                  0x882db7c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale_4                                0x882db7900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_clamp                                  0x882db7600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_tanh                                   0x882db7300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                                   0x882db7000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sigmoid                                0x882db6d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                                   0x882db6a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_4                                 0x882db6700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_erf                               0x882db6400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_erf_4                             0x882db6100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick                             0x882db5e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick_4                           0x882db5b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                                   0x882db5800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu_4                                 0x882db5500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_elu                                    0x882db5200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_abs                                    0x882db4f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sgn                                    0x882db4c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_step                                   0x882db4900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_hardswish                              0x882db4600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_hardsigmoid                            0x882db4300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_exp                                    0x882af4000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16                           0x882af7c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16_4                         0x882af7900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32                           0x882af7600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32_4                         0x882af7300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                          0x882af7000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                        0x882af6d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                           0x882e60000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                           0x882e60300 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_get_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_get_rows_q4_0                          0x882e60600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                          0x882e60900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_0                          0x882e60c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_1                          0x882e60f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                          0x882e61200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_mxfp4                         0x882e61500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                          0x882e61800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                          0x882e61b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                          0x882e61e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                          0x882e62100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                          0x882e62400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xxs                       0x882e62700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xs                        0x882e62a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_xxs                       0x882e62d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_s                         0x882e63000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_s                         0x882e63300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_s                         0x882e63600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_m                         0x882e63900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_nl                        0x882e63c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_xs                        0x882e48000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_i32                           0x882e48300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_f32                           0x882e48600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_f16                           0x882e48900 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_set_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_set_rows_q8_0                          0x882e48c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q4_0                          0x882e48f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q4_1                          0x882e49200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q5_0                          0x882e49500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_q5_1                          0x882e49800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_rows_iq4_nl                        0x882e49b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                               0x882e49e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm_mul                           0x882e4a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm_mul_add                       0x882e4a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_l2_norm                                0x882e4a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_group_norm                             0x882e4aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                                   0x882e4ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_conv_f32                           0x882e4b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32                           0x882e4b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32_group                     0x882e4b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rwkv_wkv6_f32                          0x882e4b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rwkv_wkv7_f32                          0x882e4bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32                         0x882e30000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32_c4                      0x882e30300 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_c4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_1row              (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_l4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_bf16                  (not supported)
# ggml_metal_init: loaded kernel_mul_mv_f16_f32                         0x882e30600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_c4                      0x882e30900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_1row                    0x882e30c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_l4                      0x882e30f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f16                         0x882e31200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_0_f32                        0x882e31500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_1_f32                        0x882e31800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_0_f32                        0x882e31b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_1_f32                        0x882e31e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q8_0_f32                        0x882e32100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_mxfp4_f32                       0x882e32400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_2                0x882e32700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_3                0x882e32a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_4                0x882e32d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_5                0x882e33000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_2               0x882e33300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_3               0x882e33600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_4               0x882e33900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_5               0x882e33c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_2               0x882e0c000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_3               0x882e0c300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_4               0x882e0c600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_5               0x882e0c900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_2               0x882e0cc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_3               0x882e0cf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_4               0x882e0d200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_5               0x882e0d500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_2               0x882e0d800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_3               0x882e0db00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_4               0x882e0de00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_5               0x882e0e100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_2               0x882e0e400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_3               0x882e0e700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_4               0x882e0ea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_5               0x882e0ed00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_2              0x882e0f000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_3              0x882e0f300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_4              0x882e0f600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_mxfp4_f32_r1_5              0x882e0f900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_2               0x882e0fc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_3               0x882dec000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_4               0x882dec300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_5               0x882dec600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_2               0x882dec900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_3               0x882decc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_4               0x882decf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_5               0x882ded200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_2               0x882ded500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_3               0x882ded800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_4               0x882dedb00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_5               0x882dede00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_2             0x882dee100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_3             0x882dee400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_4             0x882dee700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_5             0x882deea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q2_K_f32                        0x882deed00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q3_K_f32                        0x882def000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_K_f32                        0x882def300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_K_f32                        0x882def600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q6_K_f32                        0x882def900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xxs_f32                     0x882defc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xs_f32                      0x882dcc000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_xxs_f32                     0x882dcc300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_s_f32                       0x882dcc600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_s_f32                       0x882dcc900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_s_f32                       0x882dccc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_m_f32                       0x882dccf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_nl_f32                      0x882dcd200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_xs_f32                      0x882dcd500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f32_f32                      0x882dcd800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f16_f32                      0x882dcdb00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mv_id_q4_0_f32                     0x882dcde00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_1_f32                     0x882dce100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_0_f32                     0x882dce400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_1_f32                     0x882dce700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q8_0_f32                     0x882dcea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_mxfp4_f32                    0x882dced00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q2_K_f32                     0x882dcf000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q3_K_f32                     0x882dcf300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_K_f32                     0x882dcf600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_K_f32                     0x882dcf900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q6_K_f32                     0x882dcfc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xxs_f32                  0x882dc0000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xs_f32                   0x882dc0300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_xxs_f32                  0x882dc0600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_s_f32                    0x882dc0900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_s_f32                    0x882dc0c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_s_f32                    0x882dc0f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_m_f32                    0x882dc1200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_nl_f32                   0x882dc1500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_xs_f32                   0x882dc1800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f32_f32                         0x882dc1b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                         0x882dc1e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_bf16_f32                   (not supported)
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                        0x882dc2100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                        0x882dc2400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_0_f32                        0x882dc2700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_1_f32                        0x882dc2a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q8_0_f32                        0x882dc2d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_mxfp4_f32                       0x882dc3000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_mxfp4_f32                       0x882dc3300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                        0x882dc3600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                        0x882dc3900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                        0x882dc3c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                        0x882d0c000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                        0x882d0c300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xxs_f32                     0x882d0c600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xs_f32                      0x882d0c900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_xxs_f32                     0x882d0cc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_s_f32                       0x882d0cf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_s_f32                       0x882d0d200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_s_f32                       0x882d0d500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_m_f32                       0x882d0d800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_nl_f32                      0x882d0db00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_xs_f32                      0x882d0de00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_map0_f16                     0x882d0e100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_map1_f32                     0x882d0e400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f32_f16                      0x882d0e700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f16_f16                      0x882d0ea00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_id_bf16_f16                (not supported)
# ggml_metal_init: loaded kernel_mul_mm_id_q4_0_f16                     0x882d0ed00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_1_f16                     0x882d0f000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_0_f16                     0x882d0f300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_1_f16                     0x882d0f600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q8_0_f16                     0x882d0f900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_mxfp4_f16                    0x882d0fc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q2_K_f16                     0x882d18000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q3_K_f16                     0x882d18300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_K_f16                     0x882d18600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_K_f16                     0x882d18900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q6_K_f16                     0x882d18c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xxs_f16                  0x882d18f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xs_f16                   0x882d19200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_xxs_f16                  0x882d19500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_s_f16                    0x882d19800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_s_f16                    0x882d19b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_s_f16                    0x882d19e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_m_f16                    0x882d1a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_nl_f16                   0x882d1a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_xs_f16                   0x882d1a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f32                          0x882d1aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f16                          0x882d1ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_multi_f32                         0x882d1b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_multi_f16                         0x882d1b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_vision_f32                        0x882d1b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_vision_f16                        0x882d1b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f32                          0x882d1bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f16                          0x882d28000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f16                             0x882d28300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f32                             0x882d28600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f16                         0x882d28900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f32                         0x882d28c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f32_f32              0x882d28f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f16_f32              0x882d29200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_upscale_f32                            0x882d29500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_f32                                0x882d29800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_reflect_1d_f32                     0x882d29b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_timestep_embedding_f32                 0x882d29e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_arange_f32                             0x882d2a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_asc                    0x882d2a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_desc                   0x882d2a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_leaky_relu_f32                         0x882d2aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h64                 0x882d2ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h80                 0x882d2b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h96                 0x882d2b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h112                0x882d2b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h128                0x882d2b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h192                0x882d2bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_hk192_hv128         0x882d58000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h256                0x882d58300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_hk576_hv512         0x882d58600 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h192          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_hk192_hv128   (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h256          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_hk576_hv512   (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h64                0x882d58900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h80                0x882d58c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h96                0x882d58f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h112               0x882d59200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h128               0x882d59500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h192               0x882d59800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_hk192_hv128        0x882d59b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h256               0x882d59e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_hk576_hv512        0x882d5a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h64                0x882d5a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h80                0x882d5a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h96                0x882d5aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h112               0x882d5ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h128               0x882d5b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h192               0x882d5b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_hk192_hv128        0x882d5b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h256               0x882d5b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_hk576_hv512        0x882d5bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h64                0x881568000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h80                0x881568300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h96                0x881568600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h112               0x881568900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h128               0x881568c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h192               0x881568f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_hk192_hv128        0x881569200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h256               0x881569500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_hk576_hv512        0x881569800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h64                0x881569b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h80                0x881569e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h96                0x88156a100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h112               0x88156a400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h128               0x88156a700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h192               0x88156aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_hk192_hv128        0x88156ad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h256               0x88156b000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_hk576_hv512        0x88156b300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h64                0x88156b600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h80                0x88156b900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h96                0x88156bc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h112               0x882d80000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h128               0x882d80300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h192               0x882d80600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_hk192_hv128        0x882d80900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h256               0x882d80c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_hk576_hv512        0x882d80f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h64             0x882d81200 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h64       (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h64            0x882d81500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h64            0x882d81800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h64            0x882d81b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h64            0x882d81e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h64            0x882d82100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h96             0x882d82400 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h96       (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h96            0x882d82700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h96            0x882d82a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h96            0x882d82d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h96            0x882d83000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h96            0x882d83300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128            0x882d83600 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128           0x882d83900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128           0x882d83c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128           0x882d94000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128           0x882d94300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128           0x882d94600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h192            0x882d94900 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h192      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h192           0x882d94c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h192           0x882d94f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h192           0x882d95200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h192           0x882d95500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h192           0x882d95800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_hk192_hv128      0x882d95b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_hk192_hv128 (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_hk192_hv128      0x882d95e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_hk192_hv128      0x882d96100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_hk192_hv128      0x882d96400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_hk192_hv128      0x882d96700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_hk192_hv128      0x882d96a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256            0x882d96d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256           0x882d97000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256           0x882d97300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256           0x882d97600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256           0x882d97900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256           0x882d97c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_hk576_hv512      0x882da0000 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_hk576_hv512 (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_hk576_hv512      0x882da0300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_hk576_hv512      0x882da0600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_hk576_hv512      0x882da0900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_hk576_hv512      0x882da0c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_hk576_hv512      0x882da0f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                                0x882da1200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                                0x882da1500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                            0x882da1800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                            0x882da1b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                            0x882da1e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                            0x882da2100 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                           0x882da2400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                           0x882da2700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                           0x882da2a00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                           0x882da2d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                           0x882da3000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                         0x882da3300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f32                           0x882da3600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f16                           0x882da3900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f32                           0x882da3c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f16                           0x882da8000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f32                           0x882da8300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f16                           0x882da8600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f32                           0x882da8900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f16                           0x882da8c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f32                           0x882da8f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f16                           0x882da9200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                                 0x882da9500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                    0x882da9800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                   0x882da9b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                    0x882da9e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                    0x882daa100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_neg                                    0x882daa400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_reglu                                  0x882daa700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_geglu                                  0x882daaa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_swiglu                                 0x882daad00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_swiglu_oai                             0x882dab000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_geglu_erf                              0x882dab300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_geglu_quick                            0x882dab600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                               0x882dab900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mean                                   0x882dabc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                                 0x882dbc000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                        0x882dbc300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                        0x882dbc600 | th_max = 1024 | th_width =   32
# set_abort_callback: call
# llama_context:        CPU  output buffer size =     0.12 MiB
# create_memory: n_ctx = 1024 (padded)
# llama_kv_cache_unified: layer   0: dev = CPU
# llama_kv_cache_unified: layer   1: dev = CPU
# llama_kv_cache_unified: layer   2: dev = CPU
# llama_kv_cache_unified: layer   3: dev = CPU
# llama_kv_cache_unified: layer   4: dev = CPU
# llama_kv_cache_unified: layer   5: dev = CPU
# llama_kv_cache_unified: layer   6: dev = CPU
# llama_kv_cache_unified: layer   7: dev = CPU
# llama_kv_cache_unified: layer   8: dev = CPU
# llama_kv_cache_unified: layer   9: dev = CPU
# llama_kv_cache_unified: layer  10: dev = CPU
# llama_kv_cache_unified: layer  11: dev = CPU
# llama_kv_cache_unified: layer  12: dev = CPU
# llama_kv_cache_unified: layer  13: dev = CPU
# llama_kv_cache_unified: layer  14: dev = CPU
# llama_kv_cache_unified: layer  15: dev = CPU
# llama_kv_cache_unified: layer  16: dev = CPU
# llama_kv_cache_unified: layer  17: dev = CPU
# llama_kv_cache_unified: layer  18: dev = CPU
# llama_kv_cache_unified: layer  19: dev = CPU
# llama_kv_cache_unified: layer  20: dev = CPU
# llama_kv_cache_unified: layer  21: dev = CPU
# llama_kv_cache_unified: layer  22: dev = CPU
# llama_kv_cache_unified: layer  23: dev = CPU
# llama_kv_cache_unified: layer  24: dev = CPU
# llama_kv_cache_unified: layer  25: dev = CPU
# llama_kv_cache_unified: layer  26: dev = CPU
# llama_kv_cache_unified: layer  27: dev = CPU
# llama_kv_cache_unified: layer  28: dev = CPU
# llama_kv_cache_unified: layer  29: dev = CPU
# llama_kv_cache_unified: layer  30: dev = CPU
# llama_kv_cache_unified: layer  31: dev = CPU
# llama_kv_cache_unified:        CPU KV buffer size =   128.00 MiB
# llama_kv_cache_unified: size =  128.00 MiB (  1024 cells,  32 layers,  1/1 seqs), K (f16):   64.00 MiB, V (f16):   64.00 MiB
# llama_context: enumerating backends
# llama_context: backend_ptrs.size() = 3
# llama_context: max_nodes = 2328
# llama_context: worst-case: n_tokens = 512, n_seqs = 1, n_outputs = 0
# graph_reserve: reserving a graph for ubatch with n_tokens =  512, n_seqs =  1, n_outputs =  512
# graph_reserve: reserving a graph for ubatch with n_tokens =    1, n_seqs =  1, n_outputs =    1
# graph_reserve: reserving a graph for ubatch with n_tokens =  512, n_seqs =  1, n_outputs =  512
# llama_context:        CPU compute buffer size =   114.01 MiB
# llama_context: graph nodes  = 1126
# llama_context: graph splits = 450 (with bs=512), 1 (with bs=1)
# Metal : EMBED_LIBRARY = 1 | CPU : NEON = 1 | ARM_FMA = 1 | FP16_VA = 1 | DOTPROD = 1 | LLAMAFILE = 1 | ACCELERATE = 1 | OPENMP = 1 | REPACK = 1 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.chat_template': "{{ bos_token }}{% for message in messages %}{% if (message['role'] == 'user') != (loop.index0 % 2 == 0) %}{{ raise_exception('Conversation roles must alternate user/assistant/user/assistant/...') }}{% endif %}{% if message['role'] == 'user' %}{{ '[INST] ' + message['content'] + ' [/INST]' }}{% elif message['role'] == 'assistant' %}{{ message['content'] + eos_token}}{% else %}{{ raise_exception('Only user and assistant roles are supported!') }}{% endif %}{% endfor %}", 'tokenizer.ggml.add_eos_token': 'false', 'tokenizer.ggml.add_bos_token': 'true', 'tokenizer.ggml.padding_token_id': '0', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '8', 'llama.context_length': '32768', 'llama.attention.head_count': '32', 'llama.rope.freq_base': '1000000.000000', 'llama.rope.dimension_count': '128', 'general.file_type': '18', 'llama.feed_forward_length': '14336', 'llama.embedding_length': '4096', 'llama.block_count': '32', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'general.name': 'mistralai_mistral-7b-instruct-v0.2'}
# Available chat formats from metadata: chat_template.default
# Guessed chat format: mistral-instruct

# %% [markdown]
# ### Defining Model Response Parameters

# %%
def generate_llama_response(instruction, review):

    # System message explicitly instructing not to include the review text
    system_message = """
        [INST]<<SYS>>
        {}
        <</SYS>>[/INST]
    """.format(instruction)

    # Combine user_prompt and system_message to create the prompt
    prompt = f"{review}\n{system_message}"

    # Generate a response from the LLaMA model
    response = lcpp_llm(
        prompt=prompt,
        max_tokens=1024,
        temperature=0,
        top_p=0.95,
        repeat_penalty=1.2,
        top_k=50,
        stop=['INST'],
        echo=False,
        seed=42,
    )

    # Extract the sentiment from the response
    response_text = response["choices"][0]["text"]
    return response_text

# %% [markdown]
# - **`max_tokens`**: This parameter **specifies the maximum number of tokens that the model should generate** in response to the prompt.
#
# - **`temperature`**: This parameter **controls the randomness of the generated response**. A higher temperature value will result in a more random response, while a lower temperature value will result in a more predictable response.
#
# - **`top_p`**: This parameter **controls the diversity of the generated response by establishing a cumulative probability cutoff for token selection**. A higher value of top_p will result in a more diverse response, while a lower value will result in a less diverse response.
#
# - **`repeat_penalty`**: This parameter **controls the penalty for repeating tokens in the generated response**. A higher value of repeat_penalty will result in a lower probability of repeating tokens, while a lower value will result in a higher probability of repeating tokens.
#
# - **`top_k`**: This parameter **controls the maximum number of most-likely next tokens to consider** when generating the response at each step.
#
# - **`stop`**: This parameter is a **list of tokens that are used to dynamically stop response generation** whenever the tokens in the list are encountered.
#
# - **`echo`**: This parameter **controls whether the input (prompt) to the model should be returned** in the model response.
#
# - **`seed`**: This parameter **specifies a seed value that helps replicate results**.

# %% [markdown]
# ### Utility function

# %%
# defining a function to parse the JSON output from the model
def extract_json_data(json_str):
    try:
        # Find the indices of the opening and closing curly braces
        json_start = json_str.find('{')
        json_end = json_str.rfind('}')

        if json_start != -1 and json_end != -1:
            extracted_sentiment = json_str[json_start:json_end + 1]  # Extract the JSON object
            data_dict = json.loads(extracted_sentiment)
            return data_dict
        else:
            print(f"Warning: JSON object not found in response: {json_str}")
            return {}
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        return {}

# %% [markdown]
# ## 1. Sentiment Analysis (Llama)

# %%
# creating a copy of the data
data_1 = data.copy()

# %%
# defining the instructions for the model
instruction_1 = """
    You are an AI analyzing restaurant reviews. Classify the sentiment of the provided review into the following categories:
    - Positive
    - Negative
    - Neutral
"""

# %%
data_1['model_response'] = data_1['review_full'].apply(lambda x: generate_llama_response(instruction_1, x))
# Out:
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    2573.01 ms /   237 tokens (   10.86 ms per token,    92.11 tokens per second)
# llama_perf_context_print:        eval time =   18263.72 ms /   215 runs   (   84.95 ms per token,    11.77 tokens per second)
# llama_perf_context_print:       total time =   20899.26 ms /   452 tokens
# llama_perf_context_print:    graphs reused =        207
# Llama.generate: 1 prefix-match hit, remaining 307 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    2799.13 ms /   307 tokens (    9.12 ms per token,   109.68 tokens per second)
# llama_perf_context_print:        eval time =   15962.03 ms /   183 runs   (   87.22 ms per token,    11.46 tokens per second)
# llama_perf_context_print:       total time =   18813.83 ms /   490 tokens
# llama_perf_context_print:    graphs reused =        176
# Llama.generate: 1 prefix-match hit, remaining 97 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1136.44 ms /    97 tokens (   11.72 ms per token,    85.35 tokens per second)
# llama_perf_context_print:        eval time =   11196.03 ms /   130 runs   (   86.12 ms per token,    11.61 tokens per second)
# llama_perf_context_print:       total time =   12366.72 ms /   227 tokens
# llama_perf_context_print:    graphs reused =        125
# Llama.generate: 1 prefix-match hit, remaining 207 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1994.72 ms /   207 tokens (    9.64 ms per token,   103.77 tokens per second)
# llama_perf_context_print:        eval time =    9291.76 ms /   107 runs   (   86.84 ms per token,    11.52 tokens per second)
# llama_perf_context_print:       total time =   11311.45 ms /   314 tokens
# llama_perf_context_print:    graphs reused =        103
# Llama.generate: 1 prefix-match hit, remaining 244 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    2252.71 ms /   244 tokens (    9.23 ms per token,   108.31 tokens per second)
# llama_perf_context_print:        eval time =   21390.25 ms /   244 runs   (   87.66 ms per token,    11.41 tokens per second)
# llama_perf_context_print:       total time =   23718.28 ms /   488 tokens
# llama_perf_context_print:    graphs reused =        235
# Llama.generate: 1 prefix-match hit, remaining 287 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    2540.62 ms /   287 tokens (    8.85 ms per token,   112.96 tokens per second)
# llama_perf_context_print:        eval time =   10233.39 ms /   109 runs   (   93.88 ms per token,    10.65 tokens per second)
# llama_perf_context_print:       total time =   12807.79 ms /   396 tokens
# llama_perf_context_print:    graphs reused =        105
# Llama.generate: 2 prefix-match hit, remaining 293 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    2832.43 ms /   293 tokens (    9.67 ms per token,   103.44 tokens per second)
# llama_perf_context_print:        eval time =   13431.76 ms /   149 runs   (   90.15 ms per token,    11.09 tokens per second)
# llama_perf_context_print:       total time =   16306.71 ms /   442 tokens
# llama_perf_context_print:    graphs reused =        144
# Llama.generate: 1 prefix-match hit, remaining 132 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1457.71 ms /   132 tokens (   11.04 ms per token,    90.55 tokens per second)
# llama_perf_context_print:        eval time =    6325.14 ms /    72 runs   (   87.85 ms per token,    11.38 tokens per second)
# llama_perf_context_print:       total time =    7799.33 ms /   204 tokens
# llama_perf_context_print:    graphs reused =         69
# Llama.generate: 1 prefix-match hit, remaining 134 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1474.93 ms /   134 tokens (   11.01 ms per token,    90.85 tokens per second)
# llama_perf_context_print:        eval time =    7399.27 ms /    84 runs   (   88.09 ms per token,    11.35 tokens per second)
# llama_perf_context_print:       total time =    8893.35 ms /   218 tokens
# llama_perf_context_print:    graphs reused =         81
# Llama.generate: 1 prefix-match hit, remaining 133 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1446.11 ms /   133 tokens (   10.87 ms per token,    91.97 tokens per second)
# llama_perf_context_print:        eval time =    6664.29 ms /    76 runs   (   87.69 ms per token,    11.40 tokens per second)
# llama_perf_context_print:       total time =    8127.38 ms /   209 tokens
# llama_perf_context_print:    graphs reused =         73
# Llama.generate: 1 prefix-match hit, remaining 133 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1468.36 ms /   133 tokens (   11.04 ms per token,    90.58 tokens per second)
# llama_perf_context_print:        eval time =    7266.26 ms /    83 runs   (   87.55 ms per token,    11.42 tokens per second)
# llama_perf_context_print:       total time =    8752.45 ms /   216 tokens
# llama_perf_context_print:    graphs reused =         80
# Llama.generate: 1 prefix-match hit, remaining 133 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1430.99 ms /   133 tokens (   10.76 ms per token,    92.94 tokens per second)
# llama_perf_context_print:        eval time =    8032.08 ms /    93 runs   (   86.37 ms per token,    11.58 tokens per second)
# llama_perf_context_print:       total time =    9482.46 ms /   226 tokens
# llama_perf_context_print:    graphs reused =         89
# Llama.generate: 1 prefix-match hit, remaining 129 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1435.91 ms /   129 tokens (   11.13 ms per token,    89.84 tokens per second)
# llama_perf_context_print:        eval time =    8015.90 ms /    90 runs   (   89.07 ms per token,    11.23 tokens per second)
# llama_perf_context_print:       total time =    9470.37 ms /   219 tokens
# llama_perf_context_print:    graphs reused =         87
# Llama.generate: 1 prefix-match hit, remaining 435 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3980.45 ms /   435 tokens (    9.15 ms per token,   109.28 tokens per second)
# llama_perf_context_print:        eval time =   11914.35 ms /   134 runs   (   88.91 ms per token,    11.25 tokens per second)
# llama_perf_context_print:       total time =   15924.71 ms /   569 tokens
# llama_perf_context_print:    graphs reused =        129
# Llama.generate: 1 prefix-match hit, remaining 606 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    5404.89 ms /   606 tokens (    8.92 ms per token,   112.12 tokens per second)
# llama_perf_context_print:        eval time =   15546.19 ms /   172 runs   (   90.38 ms per token,    11.06 tokens per second)
# llama_perf_context_print:       total time =   20993.05 ms /   778 tokens
# llama_perf_context_print:    graphs reused =        165
# Llama.generate: 1 prefix-match hit, remaining 347 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3120.00 ms /   347 tokens (    8.99 ms per token,   111.22 tokens per second)
# llama_perf_context_print:        eval time =   13122.43 ms /   150 runs   (   87.48 ms per token,    11.43 tokens per second)
# llama_perf_context_print:       total time =   16277.66 ms /   497 tokens
# llama_perf_context_print:    graphs reused =        144
# Llama.generate: 1 prefix-match hit, remaining 351 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3121.83 ms /   351 tokens (    8.89 ms per token,   112.43 tokens per second)
# llama_perf_context_print:        eval time =    5474.06 ms /    63 runs   (   86.89 ms per token,    11.51 tokens per second)
# llama_perf_context_print:       total time =    8608.14 ms /   414 tokens
# llama_perf_context_print:    graphs reused =         61
# Llama.generate: 1 prefix-match hit, remaining 415 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3701.35 ms /   415 tokens (    8.92 ms per token,   112.12 tokens per second)
# llama_perf_context_print:        eval time =   10743.58 ms /   122 runs   (   88.06 ms per token,    11.36 tokens per second)
# llama_perf_context_print:       total time =   14471.07 ms /   537 tokens
# llama_perf_context_print:    graphs reused =        118
# Llama.generate: 1 prefix-match hit, remaining 545 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    5095.26 ms /   545 tokens (    9.35 ms per token,   106.96 tokens per second)
# llama_perf_context_print:        eval time =   16196.69 ms /   181 runs   (   89.48 ms per token,    11.18 tokens per second)
# llama_perf_context_print:       total time =   21337.00 ms /   726 tokens
# llama_perf_context_print:    graphs reused =        175
# Llama.generate: 1 prefix-match hit, remaining 368 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3376.17 ms /   368 tokens (    9.17 ms per token,   109.00 tokens per second)
# llama_perf_context_print:        eval time =   10425.43 ms /   119 runs   (   87.61 ms per token,    11.41 tokens per second)
# llama_perf_context_print:       total time =   13827.02 ms /   487 tokens
# llama_perf_context_print:    graphs reused =        114

# %%
data_1['model_response'].head()
# Out:
# 0     Sure, I can help you with that! Based on the ...
# 1     Sure, I can help you with that! Based on the ...
# 2     Sure, I can help you with that! Based on the ...
# 3     Sure, I can help you with that! Based on the ...
# 4     Sure, I can help you with that! Based on the ...
# Name: model_response, dtype: str

# %%
i = 2
print(data_1.loc[i, 'review_full'])
# Out:
# Excellent taste and awesome decorum. Must visit. Subham Barnwal had given us a great service. One of the best experience.

# %%
print(data_1.loc[i, 'model_response'])
# Out:
#  Sure, I can help you with that! Based on the review provided, I would classify the sentiment as Positive. Here's why:
#
# * The reviewer uses positive adjectives such as "excellent," "awesome," and "great" to describe their experience.
# * They mention specific aspects of the restaurant that they enjoyed, such as the taste and decorum.
# * There is no negative language or complaints in the review.
#
# Overall, the sentiment of the review is positive because it expresses a favorable opinion of the restaurant and highlights several positive aspects of their experience.

# %%
def extract_sentiment(model_response):
    if 'positive' in model_response.lower():
        return 'Positive'
    elif 'negative' in model_response.lower():
        return 'Negative'
    elif 'neutral' in model_response.lower():
        return 'Neutral'

# %%
# applying the function to the model response
data_1['sentiment'] = data_1['model_response'].apply(extract_sentiment)
data_1['sentiment'].head()
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: sentiment, dtype: str

# %%
data_1['sentiment'].value_counts()
# Out:
# sentiment
# Positive    16
# Negative     4
# Name: count, dtype: int64

# %%
final_data_1 = data_1.drop(['model_response'], axis=1)
final_data_1.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full sentiment
# 0  Totally in love with the Auro of the place, re...  Positive
# 1  Kailash colony is brimming with small cafes no...  Positive
# 2  Excellent taste and awesome decorum. Must visi...  Positive
# 3  I have visited at jw lough/restourant. There w...  Positive
# 4  Had a great experience in the restaurant food ...  Positive

# %% [markdown]
# ## 1. Sentiment Analysis (Mistral)

# %%
# creating a copy of the data
data_1 = data.copy()

# %% [markdown]
# **We are going to use an instruction-tuned Mistral model. Hence, the format of the input to the model varies from that of Llama.**

# %%
#Defining the response funciton for Task 1.
def response_1(prompt,review):
    model_output = llm(
      f"""
      Q: {prompt}
      Review: {review}
      A:
      """,
      max_tokens=32,
      stop=["Q:", "\n"],
      temperature=0.01,
      echo=False,
    )

    temp_output = model_output["choices"][0]["text"]

    return temp_output

# %%
# defining the instructions for the model
instruction_1 = """
    You are an AI analyzing restaurant reviews. Classify the sentiment of the provided review into the following categories:
    - Positive
    - Negative
    - Neutral
"""

# %%
data_1['model_response'] = data_1['review_full'].apply(lambda x: response_1(instruction_1, x))
# Out:
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   12897.05 ms /   218 tokens (   59.16 ms per token,    16.90 tokens per second)
# llama_perf_context_print:        eval time =    3108.95 ms /    31 runs   (  100.29 ms per token,     9.97 tokens per second)
# llama_perf_context_print:       total time =   16011.86 ms /   249 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 235 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   20498.47 ms /   235 tokens (   87.23 ms per token,    11.46 tokens per second)
# llama_perf_context_print:        eval time =    3034.93 ms /    31 runs   (   97.90 ms per token,    10.21 tokens per second)
# llama_perf_context_print:       total time =   23538.96 ms /   266 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 34 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   11757.51 ms /    34 tokens (  345.81 ms per token,     2.89 tokens per second)
# llama_perf_context_print:        eval time =    3057.97 ms /    31 runs   (   98.64 ms per token,    10.14 tokens per second)
# llama_perf_context_print:       total time =   14821.12 ms /    65 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 143 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   15705.05 ms /   143 tokens (  109.83 ms per token,     9.11 tokens per second)
# llama_perf_context_print:        eval time =    3193.98 ms /    31 runs   (  103.03 ms per token,     9.71 tokens per second)
# llama_perf_context_print:       total time =   18904.75 ms /   174 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 169 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   18229.94 ms /   169 tokens (  107.87 ms per token,     9.27 tokens per second)
# llama_perf_context_print:        eval time =    3033.82 ms /    31 runs   (   97.87 ms per token,    10.22 tokens per second)
# llama_perf_context_print:       total time =   21269.36 ms /   200 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 217 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   18538.27 ms /   217 tokens (   85.43 ms per token,    11.71 tokens per second)
# llama_perf_context_print:        eval time =    3039.42 ms /    31 runs   (   98.05 ms per token,    10.20 tokens per second)
# llama_perf_context_print:       total time =   21583.02 ms /   248 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 53 prefix-match hit, remaining 215 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   20386.24 ms /   215 tokens (   94.82 ms per token,    10.55 tokens per second)
# llama_perf_context_print:        eval time =    3179.71 ms /    31 runs   (  102.57 ms per token,     9.75 tokens per second)
# llama_perf_context_print:       total time =   23571.64 ms /   246 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 69 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   12762.93 ms /    69 tokens (  184.97 ms per token,     5.41 tokens per second)
# llama_perf_context_print:        eval time =    3033.64 ms /    31 runs   (   97.86 ms per token,    10.22 tokens per second)
# llama_perf_context_print:       total time =   15802.14 ms /   100 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 67 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   14238.76 ms /    67 tokens (  212.52 ms per token,     4.71 tokens per second)
# llama_perf_context_print:        eval time =    3034.58 ms /    31 runs   (   97.89 ms per token,    10.22 tokens per second)
# llama_perf_context_print:       total time =   17278.75 ms /    98 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 68 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   13200.49 ms /    68 tokens (  194.12 ms per token,     5.15 tokens per second)
# llama_perf_context_print:        eval time =    2995.00 ms /    31 runs   (   96.61 ms per token,    10.35 tokens per second)
# llama_perf_context_print:       total time =   16200.62 ms /    99 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 65 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   14068.31 ms /    65 tokens (  216.44 ms per token,     4.62 tokens per second)
# llama_perf_context_print:        eval time =    3058.70 ms /    31 runs   (   98.67 ms per token,    10.14 tokens per second)
# llama_perf_context_print:       total time =   17132.47 ms /    96 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 71 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   11003.58 ms /    71 tokens (  154.98 ms per token,     6.45 tokens per second)
# llama_perf_context_print:        eval time =    3037.85 ms /    31 runs   (   98.00 ms per token,    10.20 tokens per second)
# llama_perf_context_print:       total time =   14046.46 ms /   102 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 64 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   11748.76 ms /    64 tokens (  183.57 ms per token,     5.45 tokens per second)
# llama_perf_context_print:        eval time =    3031.54 ms /    31 runs   (   97.79 ms per token,    10.23 tokens per second)
# llama_perf_context_print:       total time =   14785.69 ms /    95 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 354 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   24678.48 ms /   354 tokens (   69.71 ms per token,    14.34 tokens per second)
# llama_perf_context_print:        eval time =    3041.80 ms /    31 runs   (   98.12 ms per token,    10.19 tokens per second)
# llama_perf_context_print:       total time =   27725.71 ms /   385 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 526 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   40966.93 ms /   526 tokens (   77.88 ms per token,    12.84 tokens per second)
# llama_perf_context_print:        eval time =    3143.49 ms /    31 runs   (  101.40 ms per token,     9.86 tokens per second)
# llama_perf_context_print:       total time =   44116.59 ms /   557 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 274 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   23421.79 ms /   274 tokens (   85.48 ms per token,    11.70 tokens per second)
# llama_perf_context_print:        eval time =    3157.83 ms /    31 runs   (  101.87 ms per token,     9.82 tokens per second)
# llama_perf_context_print:       total time =   26585.60 ms /   305 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 284 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   19745.05 ms /   284 tokens (   69.52 ms per token,    14.38 tokens per second)
# llama_perf_context_print:        eval time =    3046.94 ms /    31 runs   (   98.29 ms per token,    10.17 tokens per second)
# llama_perf_context_print:       total time =   22797.06 ms /   315 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 335 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   23571.34 ms /   335 tokens (   70.36 ms per token,    14.21 tokens per second)
# llama_perf_context_print:        eval time =    3133.99 ms /    31 runs   (  101.10 ms per token,     9.89 tokens per second)
# llama_perf_context_print:       total time =   26710.93 ms /   366 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 462 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   32324.15 ms /   462 tokens (   69.97 ms per token,    14.29 tokens per second)
# llama_perf_context_print:        eval time =    3081.44 ms /    31 runs   (   99.40 ms per token,    10.06 tokens per second)
# llama_perf_context_print:       total time =   35411.32 ms /   493 tokens
# llama_perf_context_print:    graphs reused =         29
# Llama.generate: 52 prefix-match hit, remaining 297 prompt tokens to eval
# llama_perf_context_print:        load time =   12897.61 ms
# llama_perf_context_print: prompt eval time =   22916.43 ms /   297 tokens (   77.16 ms per token,    12.96 tokens per second)
# llama_perf_context_print:        eval time =    3143.64 ms /    31 runs   (  101.41 ms per token,     9.86 tokens per second)
# llama_perf_context_print:       total time =   26065.96 ms /   328 tokens
# llama_perf_context_print:    graphs reused =         29

# %%
data_1['model_response'].head()
# Out:
# 0     This review expresses a very positive sentime...
# 1     Based on the provided review, the sentiment c...
# 2     Based on the provided review, the sentiment c...
# 3     Based on the provided review, the sentiment c...
# 4     Based on the provided review, the sentiment i...
# Name: model_response, dtype: str

# %%
i = 2
print(data_1.loc[i, 'review_full'])
# Out:
# Excellent taste and awesome decorum. Must visit. Subham Barnwal had given us a great service. One of the best experience.

# %%
print(data_1.loc[i, 'model_response'])
# Out:
#  Based on the provided review, the sentiment can be classified as Positive. The reviewer has expressed their enjoyment of the taste and decorum of the restaurant

# %%
def extract_sentiment(model_response):
    if 'positive' in model_response.lower():
        return 'Positive'
    elif 'negative' in model_response.lower():
        return 'Negative'
    elif 'neutral' in model_response.lower():
        return 'Neutral'

# %%
# applying the function to the model response
data_1['sentiment'] = data_1['model_response'].apply(extract_sentiment)
data_1['sentiment'].head()
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: sentiment, dtype: str

# %%
data_1['sentiment'].value_counts()
# Out:
# sentiment
# Positive    11
# Negative     7
# Neutral      2
# Name: count, dtype: int64

# %%
final_data_1 = data_1.drop(['model_response'], axis=1)
final_data_1.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full sentiment
# 0  Totally in love with the Auro of the place, re...  Positive
# 1  Kailash colony is brimming with small cafes no...  Positive
# 2  Excellent taste and awesome decorum. Must visi...  Positive
# 3  I have visited at jw lough/restourant. There w...  Positive
# 4  Had a great experience in the restaurant food ...  Positive

# %% [markdown]
# ## 2. Sentiment Analysis and Returning Structured Output (Llama)

# %%
# creating a copy of the data
data_2 = data.copy()

# %%
# defining the instructions for the model
instruction_2 = """
    You are an AI analyzing restaurant reviews. Classify the sentiment of the provided review into the following categories:
    - Positive
    - Negative
    - Neutral

    Format the output as a JSON object with a single key-value pair as shown below:
    {"sentiment": "your_sentiment_prediction"}
"""

# %%
data_2['model_response'] = data_2['review_full'].apply(lambda x: generate_llama_response(instruction_2, x))
# Out:
# Llama.generate: 1 prefix-match hit, remaining 272 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    7381.88 ms /   272 tokens (   27.14 ms per token,    36.85 tokens per second)
# llama_perf_context_print:        eval time =   11854.33 ms /   136 runs   (   87.16 ms per token,    11.47 tokens per second)
# llama_perf_context_print:       total time =   19273.90 ms /   408 tokens
# llama_perf_context_print:    graphs reused =        131
# Llama.generate: 1 prefix-match hit, remaining 343 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3145.44 ms /   343 tokens (    9.17 ms per token,   109.05 tokens per second)
# llama_perf_context_print:        eval time =   13911.67 ms /   161 runs   (   86.41 ms per token,    11.57 tokens per second)
# llama_perf_context_print:       total time =   17101.56 ms /   504 tokens
# llama_perf_context_print:    graphs reused =        155
# Llama.generate: 1 prefix-match hit, remaining 133 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1430.27 ms /   133 tokens (   10.75 ms per token,    92.99 tokens per second)
# llama_perf_context_print:        eval time =    2886.03 ms /    32 runs   (   90.19 ms per token,    11.09 tokens per second)
# llama_perf_context_print:       total time =    4324.01 ms /   165 tokens
# llama_perf_context_print:    graphs reused =         30
# Llama.generate: 1 prefix-match hit, remaining 243 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    2232.15 ms /   243 tokens (    9.19 ms per token,   108.86 tokens per second)
# llama_perf_context_print:        eval time =    9060.96 ms /   104 runs   (   87.12 ms per token,    11.48 tokens per second)
# llama_perf_context_print:       total time =   11317.88 ms /   347 tokens
# llama_perf_context_print:    graphs reused =        100
# Llama.generate: 1 prefix-match hit, remaining 280 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    2586.09 ms /   280 tokens (    9.24 ms per token,   108.27 tokens per second)
# llama_perf_context_print:        eval time =    9558.87 ms /   110 runs   (   86.90 ms per token,    11.51 tokens per second)
# llama_perf_context_print:       total time =   12171.29 ms /   390 tokens
# llama_perf_context_print:    graphs reused =        105
# Llama.generate: 1 prefix-match hit, remaining 323 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3115.05 ms /   323 tokens (    9.64 ms per token,   103.69 tokens per second)
# llama_perf_context_print:        eval time =    2548.81 ms /    30 runs   (   84.96 ms per token,    11.77 tokens per second)
# llama_perf_context_print:       total time =    5669.70 ms /   353 tokens
# llama_perf_context_print:    graphs reused =         28
# Llama.generate: 2 prefix-match hit, remaining 329 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3110.23 ms /   329 tokens (    9.45 ms per token,   105.78 tokens per second)
# llama_perf_context_print:        eval time =    8420.73 ms /    96 runs   (   87.72 ms per token,    11.40 tokens per second)
# llama_perf_context_print:       total time =   11553.02 ms /   425 tokens
# llama_perf_context_print:    graphs reused =         92
# Llama.generate: 1 prefix-match hit, remaining 168 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1713.56 ms /   168 tokens (   10.20 ms per token,    98.04 tokens per second)
# llama_perf_context_print:        eval time =    7674.56 ms /    88 runs   (   87.21 ms per token,    11.47 tokens per second)
# llama_perf_context_print:       total time =    9408.75 ms /   256 tokens
# llama_perf_context_print:    graphs reused =         84
# Llama.generate: 1 prefix-match hit, remaining 170 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1733.15 ms /   170 tokens (   10.20 ms per token,    98.09 tokens per second)
# llama_perf_context_print:        eval time =    2105.93 ms /    24 runs   (   87.75 ms per token,    11.40 tokens per second)
# llama_perf_context_print:       total time =    3844.28 ms /   194 tokens
# llama_perf_context_print:    graphs reused =         22
# Llama.generate: 1 prefix-match hit, remaining 169 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1722.34 ms /   169 tokens (   10.19 ms per token,    98.12 tokens per second)
# llama_perf_context_print:        eval time =    8706.32 ms /   100 runs   (   87.06 ms per token,    11.49 tokens per second)
# llama_perf_context_print:       total time =   10452.04 ms /   269 tokens
# llama_perf_context_print:    graphs reused =         96
# Llama.generate: 1 prefix-match hit, remaining 169 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1717.89 ms /   169 tokens (   10.17 ms per token,    98.38 tokens per second)
# llama_perf_context_print:        eval time =    2139.27 ms /    24 runs   (   89.14 ms per token,    11.22 tokens per second)
# llama_perf_context_print:       total time =    3862.09 ms /   193 tokens
# llama_perf_context_print:    graphs reused =         22
# Llama.generate: 1 prefix-match hit, remaining 169 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1707.63 ms /   169 tokens (   10.10 ms per token,    98.97 tokens per second)
# llama_perf_context_print:        eval time =    2095.01 ms /    25 runs   (   83.80 ms per token,    11.93 tokens per second)
# llama_perf_context_print:       total time =    3807.50 ms /   194 tokens
# llama_perf_context_print:    graphs reused =         23
# Llama.generate: 1 prefix-match hit, remaining 165 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    1717.65 ms /   165 tokens (   10.41 ms per token,    96.06 tokens per second)
# llama_perf_context_print:        eval time =    6813.27 ms /    78 runs   (   87.35 ms per token,    11.45 tokens per second)
# llama_perf_context_print:       total time =    8548.74 ms /   243 tokens
# llama_perf_context_print:    graphs reused =         75
# Llama.generate: 1 prefix-match hit, remaining 471 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    4275.40 ms /   471 tokens (    9.08 ms per token,   110.17 tokens per second)
# llama_perf_context_print:        eval time =   15981.05 ms /   176 runs   (   90.80 ms per token,    11.01 tokens per second)
# llama_perf_context_print:       total time =   20305.40 ms /   647 tokens
# llama_perf_context_print:    graphs reused =        169
# Llama.generate: 1 prefix-match hit, remaining 642 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    6050.29 ms /   642 tokens (    9.42 ms per token,   106.11 tokens per second)
# llama_perf_context_print:        eval time =   10044.50 ms /   110 runs   (   91.31 ms per token,    10.95 tokens per second)
# llama_perf_context_print:       total time =   16122.07 ms /   752 tokens
# llama_perf_context_print:    graphs reused =        106
# Llama.generate: 1 prefix-match hit, remaining 383 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3445.01 ms /   383 tokens (    8.99 ms per token,   111.18 tokens per second)
# llama_perf_context_print:        eval time =   15077.47 ms /   168 runs   (   89.75 ms per token,    11.14 tokens per second)
# llama_perf_context_print:       total time =   18569.17 ms /   551 tokens
# llama_perf_context_print:    graphs reused =        162
# Llama.generate: 1 prefix-match hit, remaining 387 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3697.71 ms /   387 tokens (    9.55 ms per token,   104.66 tokens per second)
# llama_perf_context_print:        eval time =    4276.58 ms /    47 runs   (   90.99 ms per token,    10.99 tokens per second)
# llama_perf_context_print:       total time =    7985.48 ms /   434 tokens
# llama_perf_context_print:    graphs reused =         45
# Llama.generate: 1 prefix-match hit, remaining 451 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    4277.86 ms /   451 tokens (    9.49 ms per token,   105.43 tokens per second)
# llama_perf_context_print:        eval time =   12591.61 ms /   138 runs   (   91.24 ms per token,    10.96 tokens per second)
# llama_perf_context_print:       total time =   16906.48 ms /   589 tokens
# llama_perf_context_print:    graphs reused =        133
# Llama.generate: 1 prefix-match hit, remaining 581 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    5903.91 ms /   581 tokens (   10.16 ms per token,    98.41 tokens per second)
# llama_perf_context_print:        eval time =   19160.14 ms /   208 runs   (   92.12 ms per token,    10.86 tokens per second)
# llama_perf_context_print:       total time =   25128.17 ms /   789 tokens
# llama_perf_context_print:    graphs reused =        201
# Llama.generate: 1 prefix-match hit, remaining 404 prompt tokens to eval
# llama_perf_context_print:        load time =    2573.60 ms
# llama_perf_context_print: prompt eval time =    3711.11 ms /   404 tokens (    9.19 ms per token,   108.86 tokens per second)
# llama_perf_context_print:        eval time =    2805.70 ms /    32 runs   (   87.68 ms per token,    11.41 tokens per second)
# llama_perf_context_print:       total time =    6523.31 ms /   436 tokens
# llama_perf_context_print:    graphs reused =         30

# %%
data_2['model_response'].head()
# Out:
# 0     Sure, I can help you with that! Here's the se...
# 1     Sure, I can help you with that! Here's the se...
# 2     Sure, I can help you with that! Based on the ...
# 3     Sure, I can help you with that! Here's the se...
# 4     Sure, I can help you with that! Based on the ...
# Name: model_response, dtype: str

# %%
i = 2
print(data_2.loc[i, 'review_full'])
# Out:
# Excellent taste and awesome decorum. Must visit. Subham Barnwal had given us a great service. One of the best experience.

# %%
print(data_2.loc[i, 'model_response'])
# Out:
#  Sure, I can help you with that! Based on the review provided, here's my sentiment analysis:
#
# {"sentiment": "Positive"}

# %%
# applying the function to the model response
data_2['model_response_parsed'] = data_2['model_response'].apply(extract_json_data)
data_2['model_response_parsed'].head()
# Out:
# 0    {'sentiment': 'Positive'}
# 1    {'sentiment': 'Positive'}
# 2    {'sentiment': 'Positive'}
# 3    {'sentiment': 'Positive'}
# 4    {'sentiment': 'Positive'}
# Name: model_response_parsed, dtype: object

# %%
model_response_parsed_df_2 = pd.json_normalize(data_2['model_response_parsed'])
model_response_parsed_df_2.head()
# Out:
#   sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
data_with_parsed_model_output_2 = pd.concat([data_2, model_response_parsed_df_2], axis=1)
data_with_parsed_model_output_2.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full  \
# 0  Totally in love with the Auro of the place, re...
# 1  Kailash colony is brimming with small cafes no...
# 2  Excellent taste and awesome decorum. Must visi...
# 3  I have visited at jw lough/restourant. There w...
# 4  Had a great experience in the restaurant food ...
#
#                                       model_response  \
# 0   Sure, I can help you with that! Here's the se...
# 1   Sure, I can help you with that! Here's the se...
# 2   Sure, I can help you with that! Based on the ...
# 3   Sure, I can help you with that! Here's the se...
# 4   Sure, I can help you with that! Based on the ...
#
#        model_response_parsed sentiment
# 0  {'sentiment': 'Positive'}  Positive
# 1  {'sentiment': 'Positive'}  Positive
# 2  {'sentiment': 'Positive'}  Positive
# 3  {'sentiment': 'Positive'}  Positive
# 4  {'sentiment': 'Positive'}  Positive

# %%
final_data_2 = data_with_parsed_model_output_2.drop(['model_response','model_response_parsed'], axis=1)
final_data_2.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full sentiment
# 0  Totally in love with the Auro of the place, re...  Positive
# 1  Kailash colony is brimming with small cafes no...  Positive
# 2  Excellent taste and awesome decorum. Must visi...  Positive
# 3  I have visited at jw lough/restourant. There w...  Positive
# 4  Had a great experience in the restaurant food ...  Positive

# %%
final_data_2['sentiment'].value_counts()
# Out:
# sentiment
# Neutral     7
# Negative    7
# Positive    6
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Identifying Overall Sentiment and Sentiment of Aspects of the Experience (Llama)

# %%
# creating a copy of the data
data_3 = data.copy()

# %%
# defining the instructions for the model
instruction_3 = """
    You are an AI analyzing restaurant reviews. Classify the overall sentiment of the provided review into the following categories:
    - "Positive"
    - "Negative"
    - "Neutral"

    Once that is done, check for a mention of the following aspects in the review and classify the sentiment of each aspect as "Positive", "Negative", or "Neutral":
    1. "Food Quality"
    2. "Service"
    3. "Ambience"

    Output the overall sentiment and sentiment for each category in a JSON format with the following keys:
    {
        "Overall": "your_sentiment_prediction",
        "Food Quality": "your_sentiment_prediction",
        "Service": "your_sentiment_prediction",
        "Ambience": "your_sentiment_prediction"
    }

    In case one of the three aspects is not mentioned in the review, set "Not Applicable" (including quotes) for the corresponding JSON key value.
    Only return the JSON, do not return any other information.
"""

# %%
data_3['model_response'] = data_3['review_full'].apply(lambda x: generate_llama_response(instruction_3, x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 data_3['model_response'] = data_3['review_full'].apply(lambda x: generate_llama_response(instruction_3, x))
#
# File ~/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages/pandas/core/arrays/base.py:2692, in ExtensionArray.map(self, mapper, na_action)
#    2672 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2673     """
#    2674     Map values using an input mapping or function.
#    2675
#    (...)   2690         a MultiIndex will be returned.
#    2691     """
# -> 2692     return map_array(self, mapper, na_action=na_action)
#
# File ~/Documents/Code/AI-ML-Experiments/.venv-metal/lib/python3.13/site-packages/pandas/core/algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[60], line 1, in <lambda>(x)
# ----> 1 data_3['model_response'] = data_3['review_full'].apply(lambda x: generate_llama_response(instruction_3, x))
#
# NameError: name 'instruction_3' is not defined

# %%
data_3['model_response'].head()
# Out:
# 0     {\n        "Overall": "Positive",\n        "F...
# 1     {\n            "Overall": "Positive",\n      ...
# 2     {\n       "Overall": "Positive",\n       "Foo...
# 3     {\n        "Overall": "Positive",\n        "F...
# 4     {\n       "Overall": "Positive",\n       "Foo...
# Name: model_response, dtype: object

# %%
i = 2
print(data_3.loc[i, 'review_full'])
# Out:
# Excellent taste and awesome decorum. Must visit. Subham Barnwal had given us a great service. One of the best experience.

# %%
print(data_3.loc[i, 'model_response'])
# Out:
#  {
#        "Overall": "Positive",
#        "Food Quality": "Positive",
#        "Service": "Positive",
#        "Ambience": "Neutral"
#     }

# %%
# applying the function to the model response
data_3['model_response_parsed'] = data_3['model_response'].apply(extract_json_data)
data_3['model_response_parsed'].head()
# Out:
# 0    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 1    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 2    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 3    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 4    {'Overall': 'Positive', 'Food Quality': 'Posit...
# Name: model_response_parsed, dtype: object

# %%
model_response_parsed_df_3 = pd.json_normalize(data_3['model_response_parsed'])
model_response_parsed_df_3.head()
# Out:
#     Overall Food Quality   Service  Ambience
# 0  Positive     Positive  Positive  Positive
# 1  Positive     Positive   Neutral  Positive
# 2  Positive     Positive  Positive   Neutral
# 3  Positive     Positive  Positive   Neutral
# 4  Positive     Positive  Positive   Neutral

# %%
data_with_parsed_model_output_3 = pd.concat([data_3, model_response_parsed_df_3], axis=1)
data_with_parsed_model_output_3.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full  \
# 0  Totally in love with the Auro of the place, re...
# 1  Kailash colony is brimming with small cafes no...
# 2  Excellent taste and awesome decorum. Must visi...
# 3  I have visited at jw lough/restourant. There w...
# 4  Had a great experience in the restaurant food ...
#
#                                       model_response  \
# 0   {\n        "Overall": "Positive",\n        "F...
# 1   {\n            "Overall": "Positive",\n      ...
# 2   {\n       "Overall": "Positive",\n       "Foo...
# 3   {\n        "Overall": "Positive",\n        "F...
# 4   {\n       "Overall": "Positive",\n       "Foo...
#
#                                model_response_parsed   Overall Food Quality  \
# 0  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 1  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 2  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 3  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 4  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
#
#     Service  Ambience
# 0  Positive  Positive
# 1   Neutral  Positive
# 2  Positive   Neutral
# 3  Positive   Neutral
# 4  Positive   Neutral

# %%
final_data_3 = data_with_parsed_model_output_3.drop(['model_response','model_response_parsed'], axis=1)
final_data_3.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full   Overall Food Quality  \
# 0  Totally in love with the Auro of the place, re...  Positive     Positive
# 1  Kailash colony is brimming with small cafes no...  Positive     Positive
# 2  Excellent taste and awesome decorum. Must visi...  Positive     Positive
# 3  I have visited at jw lough/restourant. There w...  Positive     Positive
# 4  Had a great experience in the restaurant food ...  Positive     Positive
#
#     Service  Ambience
# 0  Positive  Positive
# 1   Neutral  Positive
# 2  Positive   Neutral
# 3  Positive   Neutral
# 4  Positive   Neutral

# %%
final_data_3['Overall'].value_counts()
# Out:
# Neutral     7
# Negative    7
# Positive    6
# Name: Overall, dtype: int64

# %%
final_data_3['Food Quality'].value_counts()
# Out:
# Positive          7
# Neutral           6
# Negative          3
# Mixed             3
# Not Applicable    1
# Name: Food Quality, dtype: int64

# %%
final_data_3['Service'].value_counts()
# Out:
# Positive        9
# Negative        8
# Neutral         1
# Slow            1
# Inconsistent    1
# Name: Service, dtype: int64

# %%
final_data_3['Ambience'].value_counts()
# Out:
# Not Applicable    8
# Neutral           6
# Positive          5
# Neutrial          1
# Name: Ambience, dtype: int64

# %% [markdown]
# ## 3. Identifying Overall Sentiment and Sentiment of Aspects of the Experience (Mistral)

# %%
# creating a copy of the data
data_3 = data.copy()

# %%
def response_2(prompt,review,sentiment):
    model_output = llm(
      f"""
      Q: {prompt}
      review: {review}
      sentiment: {sentiment}
      A:
      """,
      max_tokens=64,
      stop=["Q:", "\n"],
      temperature=0.01,
      echo=False,
    )

    temp_output = model_output["choices"][0]["text"]
    final_output = temp_output[temp_output.index('{'):]

    return final_output

# %% [markdown]
# **Note:** We have already predicted the sentiment of the review. We can use this information while designing the prompt for this task. This way, it will reduce the computational complexity.
#
# The sentiment is stored in the 'final_data_1' dataframe which is from the TASK 1.

# %%
# defining the instructions for the model
instruction_3 = """
    You are provided a review and it's sentiment.

    Instructions:
    Classify the sentiment of each aspect as either of "Positive", "Negative", or "Neutral" only and not any other for the given review:
    1. "Food Quality"
    2. "Service"
    3. "Ambience"
    In case one of the three aspects is not mentioned in the review, return "Not Applicable" (including quotes) for the corresponding JSON key value.
    Return the output in the format {"Overall": given sentiment input,"Food Quality": "your_sentiment_prediction","Service": "your_sentiment_prediction","Ambience": "your_sentiment_prediction"}

"""

# %%
data_3['model_response'] = final_data_1[['review_full','sentiment']].apply(lambda x: response_2(instruction_3, x[0],x[1]),axis=1)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.65 ms /    31 runs   (    0.57 ms per token,  1756.17 tokens per second)
# llama_print_timings: prompt eval time =    3303.27 ms /   249 tokens (   13.27 ms per token,    75.38 tokens per second)
# llama_print_timings:        eval time =   25245.10 ms /    30 runs   (  841.50 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   28684.42 ms /   279 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      18.34 ms /    33 runs   (    0.56 ms per token,  1798.95 tokens per second)
# llama_print_timings: prompt eval time =    2871.49 ms /   241 tokens (   11.91 ms per token,    83.93 tokens per second)
# llama_print_timings:        eval time =   26837.59 ms /    32 runs   (  838.67 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   29848.71 ms /   273 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.73 ms /    31 runs   (    0.57 ms per token,  1747.96 tokens per second)
# llama_print_timings: prompt eval time =    1776.69 ms /    40 tokens (   44.42 ms per token,    22.51 tokens per second)
# llama_print_timings:        eval time =   25208.87 ms /    30 runs   (  840.30 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   27119.78 ms /    70 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      19.13 ms /    35 runs   (    0.55 ms per token,  1829.97 tokens per second)
# llama_print_timings: prompt eval time =    2261.85 ms /   149 tokens (   15.18 ms per token,    65.88 tokens per second)
# llama_print_timings:        eval time =   28326.64 ms /    34 runs   (  833.14 ms per token,     1.20 tokens per second)
# llama_print_timings:       total time =   30735.15 ms /   183 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      18.50 ms /    33 runs   (    0.56 ms per token,  1783.88 tokens per second)
# llama_print_timings: prompt eval time =    2409.66 ms /   175 tokens (   13.77 ms per token,    72.62 tokens per second)
# llama_print_timings:        eval time =   27254.80 ms /    32 runs   (  851.71 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   29806.55 ms /   207 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.42 ms /    31 runs   (    0.56 ms per token,  1779.77 tokens per second)
# llama_print_timings: prompt eval time =    2718.27 ms /   223 tokens (   12.19 ms per token,    82.04 tokens per second)
# llama_print_timings:        eval time =   25130.51 ms /    30 runs   (  837.68 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   27981.11 ms /   253 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      19.31 ms /    32 runs   (    0.60 ms per token,  1657.34 tokens per second)
# llama_print_timings: prompt eval time =    2741.80 ms /   221 tokens (   12.41 ms per token,    80.60 tokens per second)
# llama_print_timings:        eval time =   26077.66 ms /    31 runs   (  841.21 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   28954.62 ms /   252 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      19.56 ms /    34 runs   (    0.58 ms per token,  1738.60 tokens per second)
# llama_print_timings: prompt eval time =    1955.94 ms /    75 tokens (   26.08 ms per token,    38.34 tokens per second)
# llama_print_timings:        eval time =   27699.73 ms /    33 runs   (  839.39 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   29800.48 ms /   108 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.61 ms /    32 runs   (    0.55 ms per token,  1817.67 tokens per second)
# llama_print_timings: prompt eval time =    1807.59 ms /    73 tokens (   24.76 ms per token,    40.39 tokens per second)
# llama_print_timings:        eval time =   25957.77 ms /    31 runs   (  837.35 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   27897.80 ms /   104 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      21.63 ms /    35 runs   (    0.62 ms per token,  1618.42 tokens per second)
# llama_print_timings: prompt eval time =    1838.61 ms /    75 tokens (   24.51 ms per token,    40.79 tokens per second)
# llama_print_timings:        eval time =   28560.88 ms /    34 runs   (  840.03 ms per token,     1.19 tokens per second)
# llama_print_timings:       total time =   30549.94 ms /   109 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.95 ms /    33 runs   (    0.54 ms per token,  1838.75 tokens per second)
# llama_print_timings: prompt eval time =    1829.72 ms /    72 tokens (   25.41 ms per token,    39.35 tokens per second)
# llama_print_timings:        eval time =   26723.92 ms /    32 runs   (  835.12 ms per token,     1.20 tokens per second)
# llama_print_timings:       total time =   28689.94 ms /   104 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.39 ms /    32 runs   (    0.54 ms per token,  1840.24 tokens per second)
# llama_print_timings: prompt eval time =    1846.12 ms /    77 tokens (   23.98 ms per token,    41.71 tokens per second)
# llama_print_timings:        eval time =   25792.28 ms /    31 runs   (  832.01 ms per token,     1.20 tokens per second)
# llama_print_timings:       total time =   27770.75 ms /   108 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.81 ms /    32 runs   (    0.56 ms per token,  1796.34 tokens per second)
# llama_print_timings: prompt eval time =    1881.97 ms /    71 tokens (   26.51 ms per token,    37.73 tokens per second)
# llama_print_timings:        eval time =   26260.18 ms /    31 runs   (  847.10 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   28278.08 ms /   102 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      18.80 ms /    34 runs   (    0.55 ms per token,  1808.99 tokens per second)
# llama_print_timings: prompt eval time =    3914.28 ms /   360 tokens (   10.87 ms per token,    91.97 tokens per second)
# llama_print_timings:        eval time =   28025.58 ms /    33 runs   (  849.26 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   32085.02 ms /   393 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      18.30 ms /    33 runs   (    0.55 ms per token,  1803.57 tokens per second)
# llama_print_timings: prompt eval time =   17416.86 ms /   532 tokens (   32.74 ms per token,    30.55 tokens per second)
# llama_print_timings:        eval time =   27239.34 ms /    32 runs   (  851.23 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   44799.24 ms /   564 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      19.08 ms /    34 runs   (    0.56 ms per token,  1781.60 tokens per second)
# llama_print_timings: prompt eval time =    3233.00 ms /   280 tokens (   11.55 ms per token,    86.61 tokens per second)
# llama_print_timings:        eval time =   28058.30 ms /    33 runs   (  850.25 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   31439.50 ms /   313 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      18.20 ms /    33 runs   (    0.55 ms per token,  1813.39 tokens per second)
# llama_print_timings: prompt eval time =    3320.07 ms /   290 tokens (   11.45 ms per token,    87.35 tokens per second)
# llama_print_timings:        eval time =   27085.72 ms /    32 runs   (  846.43 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   30544.46 ms /   322 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      18.52 ms /    33 runs   (    0.56 ms per token,  1782.15 tokens per second)
# llama_print_timings: prompt eval time =    3730.66 ms /   341 tokens (   10.94 ms per token,    91.40 tokens per second)
# llama_print_timings:        eval time =   27500.36 ms /    32 runs   (  859.39 ms per token,     1.16 tokens per second)
# llama_print_timings:       total time =   31378.48 ms /   373 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      17.50 ms /    31 runs   (    0.56 ms per token,  1771.53 tokens per second)
# llama_print_timings: prompt eval time =    4892.60 ms /   468 tokens (   10.45 ms per token,    95.65 tokens per second)
# llama_print_timings:        eval time =   25734.75 ms /    30 runs   (  857.82 ms per token,     1.17 tokens per second)
# llama_print_timings:       total time =   30765.13 ms /   498 tokens
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    2933.04 ms
# llama_print_timings:      sample time =      18.04 ms /    32 runs   (    0.56 ms per token,  1773.84 tokens per second)
# llama_print_timings: prompt eval time =    3682.58 ms /   303 tokens (   12.15 ms per token,    82.28 tokens per second)
# llama_print_timings:        eval time =   26201.32 ms /    31 runs   (  845.20 ms per token,     1.18 tokens per second)
# llama_print_timings:       total time =   30023.12 ms /   334 tokens

# %%
data_3['model_response'].values
# Out:
# array(['{"Overall": "Positive","Food Quality": "Positive","Service": "Positive","Ambience": "Positive"}',
#        '{"Overall": "Positive","Food Quality": "Positive","Service": "Not Applicable","Ambience": "Positive"}',
#        '{"Overall": "Positive","Food Quality": "Positive","Service": "Positive","Ambience": "Positive"}',
#        '{"Overall": "Positive","Food Quality": "Not Applicable","Service": "Positive","Ambience": "Not Applicable"}',
#        '{"Overall": "Positive","Food Quality": "Positive","Service": "Positive","Ambience": "Not Applicable"}',
#        '{"Overall": "Positive","Food Quality": "Positive","Service": "Positive","Ambience": "Positive"}',
#        '{"Overall": "Positive","Food Quality": "Neutral","Service": "Positive","Ambience": "Positive"}',
#        '{"Overall": "Positive","Food Quality": "Neutral","Service": "Negative","Ambience": "Not Applicable"}',
#        '{"Overall": "Positive","Food Quality": "Neutral","Service": "Negative","Ambience": "Positive"}',
#        '{"Overall": "Neutral","Food Quality": "If not exceptional","Service": "Positive","Ambience": "Not Applicable"}',
#        '{"Overall": "Neutral","Food Quality": "Neutral","Service": "Positive","Ambience": "Positive"}',
#        '{"Overall": "Positive","Food Quality": "Neutral","Service": "Negative","Ambience": "Positive"}',
#        '{"Overall": "Neutral","Food Quality": "Negative","Service": "Positive","Ambience": "Positive"}',
#        '{"Overall": "Negative","Food Quality": "Not Applicable","Service": "Negative","Ambience": "Neutral"}',
#        '{"Overall": "Negative","Food Quality": "Negative","Service": "Negative","Ambience": "Not Applicable"}',
#        '{"Overall": "Negative","Food Quality": "Neutral","Service": "Negative","Ambience": "Not Applicable"}',
#        '{"Overall": "Negative","Food Quality": "Not Applicable","Service": "Negative","Ambience": "Negative"}',
#        '{"Overall": "Negative","Food Quality": "Not Applicable","Service": "Negative","Ambience": "Negative"}',
#        '{"Overall": "Negative","Food Quality": "Negative","Service": "Negative","Ambience": "Negative"}',
#        '{"Overall": "Negative","Food Quality": "Positive","Service": "Negative","Ambience": "Neutral"}'],
#       dtype=object)

# %%
i = 2
print(data_3.loc[i, 'review_full'])
# Out:
# Excellent taste and awesome decorum. Must visit. Subham Barnwal had given us a great service. One of the best experience.

# %%
print(data_3.loc[i, 'model_response'])
# Out:
# {"Overall": "Positive","Food Quality": "Positive","Service": "Positive","Ambience": "Positive"}

# %%
# applying the function to the model response
data_3['model_response_parsed'] = data_3['model_response'].apply(extract_json_data)
data_3['model_response_parsed']
# Out:
# 0     {'Overall': 'Positive', 'Food Quality': 'Posit...
# 1     {'Overall': 'Positive', 'Food Quality': 'Posit...
# 2     {'Overall': 'Positive', 'Food Quality': 'Posit...
# 3     {'Overall': 'Positive', 'Food Quality': 'Not A...
# 4     {'Overall': 'Positive', 'Food Quality': 'Posit...
# 5     {'Overall': 'Positive', 'Food Quality': 'Posit...
# 6     {'Overall': 'Positive', 'Food Quality': 'Neutr...
# 7     {'Overall': 'Positive', 'Food Quality': 'Neutr...
# 8     {'Overall': 'Positive', 'Food Quality': 'Neutr...
# 9     {'Overall': 'Neutral', 'Food Quality': 'If not...
# 10    {'Overall': 'Neutral', 'Food Quality': 'Neutra...
# 11    {'Overall': 'Positive', 'Food Quality': 'Neutr...
# 12    {'Overall': 'Neutral', 'Food Quality': 'Negati...
# 13    {'Overall': 'Negative', 'Food Quality': 'Not A...
# 14    {'Overall': 'Negative', 'Food Quality': 'Negat...
# 15    {'Overall': 'Negative', 'Food Quality': 'Neutr...
# 16    {'Overall': 'Negative', 'Food Quality': 'Not A...
# 17    {'Overall': 'Negative', 'Food Quality': 'Not A...
# 18    {'Overall': 'Negative', 'Food Quality': 'Negat...
# 19    {'Overall': 'Negative', 'Food Quality': 'Posit...
# Name: model_response_parsed, dtype: object

# %%
model_response_parsed_df_3 = pd.json_normalize(data_3['model_response_parsed'])
model_response_parsed_df_3
# Out:
#      Overall        Food Quality         Service        Ambience
# 0   Positive            Positive        Positive        Positive
# 1   Positive            Positive  Not Applicable        Positive
# 2   Positive            Positive        Positive        Positive
# 3   Positive      Not Applicable        Positive  Not Applicable
# 4   Positive            Positive        Positive  Not Applicable
# 5   Positive            Positive        Positive        Positive
# 6   Positive             Neutral        Positive        Positive
# 7   Positive             Neutral        Negative  Not Applicable
# 8   Positive             Neutral        Negative        Positive
# 9    Neutral  If not exceptional        Positive  Not Applicable
# 10   Neutral             Neutral        Positive        Positive
# 11  Positive             Neutral        Negative        Positive
# 12   Neutral            Negative        Positive        Positive
# 13  Negative      Not Applicable        Negative         Neutral
# 14  Negative            Negative        Negative  Not Applicable
# 15  Negative             Neutral        Negative  Not Applicable
# 16  Negative      Not Applicable        Negative        Negative
# 17  Negative      Not Applicable        Negative        Negative
# 18  Negative            Negative        Negative        Negative
# 19  Negative            Positive        Negative         Neutral

# %%
model_response_parsed_df_3 = model_response_parsed_df_3.apply(lambda x: x.astype(str).str.lower())

# %%
data_with_parsed_model_output_3 = pd.concat([data_3, model_response_parsed_df_3], axis=1)
data_with_parsed_model_output_3.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full  \
# 0  Totally in love with the Auro of the place, re...
# 1  Kailash colony is brimming with small cafes no...
# 2  Excellent taste and awesome decorum. Must visi...
# 3  I have visited at jw lough/restourant. There w...
# 4  Had a great experience in the restaurant food ...
#
#                                       model_response  \
# 0  {"Overall": "Positive","Food Quality": "Positi...
# 1  {"Overall": "Positive","Food Quality": "Positi...
# 2  {"Overall": "Positive","Food Quality": "Positi...
# 3  {"Overall": "Positive","Food Quality": "Not Ap...
# 4  {"Overall": "Positive","Food Quality": "Positi...
#
#                                model_response_parsed   Overall  \
# 0  {'Overall': 'Positive', 'Food Quality': 'Posit...  positive
# 1  {'Overall': 'Positive', 'Food Quality': 'Posit...  positive
# 2  {'Overall': 'Positive', 'Food Quality': 'Posit...  positive
# 3  {'Overall': 'Positive', 'Food Quality': 'Not A...  positive
# 4  {'Overall': 'Positive', 'Food Quality': 'Posit...  positive
#
#      Food Quality         Service        Ambience
# 0        positive        positive        positive
# 1        positive  not applicable        positive
# 2        positive        positive        positive
# 3  not applicable        positive  not applicable
# 4        positive        positive  not applicable

# %%
final_data_3 = data_with_parsed_model_output_3.drop(['model_response','model_response_parsed'], axis=1)
final_data_3.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full   Overall  \
# 0  Totally in love with the Auro of the place, re...  positive
# 1  Kailash colony is brimming with small cafes no...  positive
# 2  Excellent taste and awesome decorum. Must visi...  positive
# 3  I have visited at jw lough/restourant. There w...  positive
# 4  Had a great experience in the restaurant food ...  positive
#
#      Food Quality         Service        Ambience
# 0        positive        positive        positive
# 1        positive  not applicable        positive
# 2        positive        positive        positive
# 3  not applicable        positive  not applicable
# 4        positive        positive  not applicable

# %%
final_data_3['Overall'].value_counts()
# Out:
# Overall
# positive    10
# negative     7
# neutral      3
# Name: count, dtype: int64

# %%
final_data_3['Food Quality'].value_counts()
# Out:
# Food Quality
# positive              6
# neutral               6
# not applicable        4
# negative              3
# if not exceptional    1
# Name: count, dtype: int64

# %% [markdown]
# **Note:** One of the sentiment is 'if not exceptional'. This is most likely positive.

# %%
final_data_3['Service'].value_counts()
# Out:
# Service
# negative          10
# positive           9
# not applicable     1
# Name: count, dtype: int64

# %%
final_data_3['Ambience'].value_counts()
# Out:
# Ambience
# positive          9
# not applicable    6
# negative          3
# neutral           2
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Identifying Overall Sentiment, Sentiment of Aspects of the Experience, and the Liked/Disliked Features of the Different Aspects of the Experience (Llama)

# %%
# creating a copy of the data
data_4 = data.copy()

# %%
# defining the instructions for the model
instruction_4 = """
    You are an AI tasked with analyzing restaurant reviews. Your goal is to classify the overall sentiment of the provided review into the following categories:
        - Positive
        - Negative
        - Neutral

    Subsequently, assess the sentiment of specific aspects mentioned in the review, namely:
        1. Food quality
        2. Service
        3. Ambience

    Further, identify liked and/or disliked features associated with each aspect in the review.

    Return the output in the specified JSON format, ensuring consistency and handling missing values appropriately:

    {
        "Overall": "your_sentiment_prediction",
        "Food Quality": "your_sentiment_prediction",
        "Service": "your_sentiment_prediction",
        "Ambience": "your_sentiment_prediction",
        "Food Quality Features": ["liked/disliked features"],
        "Service Features": ["liked/disliked features"],
        "Ambience Features": ["liked/disliked features"]
    }

    The sentiment prediction for Overall, Food Quality, Service, and Ambience should be one of "Positive", "Negative", or "Neutral" only.
    In case one of the three aspects is not mentioned in the review, set "Not Applicable" (including quotes) in the corresponding JSON key value for the sentiment.
    In case there are no liked/disliked features for a particular aspect, assign an empty list in the corresponding JSON key value for the aspect.
    Only return the JSON, do NOT return any other text or information.
"""

# %%
data_4['model_response'] = data_4['review_full'].apply(lambda x: generate_llama_response(instruction_4, x).replace('\n', ''))
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit

# %%
i = 2
print(data_4.loc[i, 'review_full'])
# Out:
# Excellent taste and awesome decorum. Must visit. Subham Barnwal had given us a great service. One of the best experience.

# %%
print(data_4.loc[i, 'model_response'])
# Out:
#  Sure! I can assist you with that. Here's my analysis of your restaurant review:{"Overall": "Positive","Food Quality": "Positive","Service": "Positive","Ambience": "Neutral","Food Quality Features": ["Excellent taste"],"Service Features": ["Great service"],"Ambience Features": []}Here's my breakdown of the review:* Overall sentiment is Positive, as the reviewer enjoyed their experience.* Food Quality sentiment is Positive, with the feature "Excellent taste" mentioned.* Service sentiment is Positive, with the feature "Great service" mentioned.* Ambience sentiment is Neutral, as no specific features were mentioned regarding the ambience of the restaurant.I hope this helps! Let me know if you have any further questions or need additional assistance.

# %%
# applying the function to the model response
data_4['model_response_parsed'] = data_4['model_response'].apply(extract_json_data)
data_4['model_response_parsed'].head()
# Out:
# Error parsing JSON: Expecting value: line 1 column 204 (char 203)
# Error parsing JSON: Extra data: line 1 column 95 (char 94)
# Error parsing JSON: Extra data: line 1 column 97 (char 96)
# 0    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 1    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 2    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 3                                                   {}
# 4    {'Overall': 'Positive', 'Food Quality': 'Posit...
# Name: model_response_parsed, dtype: object

# %%
data_4[data_4.model_response_parsed == {}]
# Out:
#   restaurant_ID  rating_review  \
# 3        TST101              5
# 6        DSH404              5
# 7        GRT505              3
#
#                                          review_full  \
# 3  I have visited at jw lough/restourant. There w...
# 6  We went there on birthday special time. A nice...
# 7  Our visit to Green Bites on a busy Saturday ev...
#
#                                       model_response model_response_parsed
# 3   Sure! I can assist you with that. Here's my a...                    {}
# 6   Sure! Here's my analysis of your restaurant r...                    {}
# 7   Sure! Here's my analysis of your restaurant r...                    {}

# %% [markdown]
# - There are three model responses that the JSON parser function could not parse
# - We'll manually add the values for these three responses

# %%
print(data_4.loc[3, 'model_response'])
# Out:
#  Sure! I can assist you with that. Here's my analysis of your provided review: Overall Sentiment: PositiveThe overall sentiment of this review is positive because the reviewer enjoyed their experience at JW Marriott Hotel, Delhi and appreciated the service quality. They also mentioned enjoying Ms. Laxmi's specialty in handling client needs. The positive tone throughout the review indicates a positive overall sentiment. Food Quality Sentiment: PositiveThe reviewer enjoyed the food at JW Marriott Hotel, Delhi and appreciated its quality. They did not mention any specific liked or disliked features for this aspect. Therefore, I will assign an empty list in the JSON key value for "Food Quality Features". Service Sentiment: PositiveThe reviewer praised Ms. Laxmi's exceptional service and appreciated her specialty in handling client needs. They also mentioned that they would definitely serve from her again, indicating a positive sentiment towards the service quality. The liked features for this aspect include Ms. Laxmi's excellent service and specialty. Ambience Sentiment: NeutralThe reviewer did not mention anything about the ambience of JW Marriott Hotel, Delhi in their review. Therefore, I will assign "Not Applicable" (including quotes) in the JSON key value for "Ambience Features". Here's the output in the specified JSON format:{    "Overall": "Positive",    "Food Quality": {        "Features": []    },    "Service": {        "Features": ["Ms. Laxmi's excellent service and specialty"]    },    "Ambience": {        "Features": [Not Applicable]    }}

# %%
print(data_4.loc[6, 'model_response'])
# Out:
#  Sure! Here's my analysis of your restaurant review:{"Overall": "Neutral","Food Quality": "Positive","Service": "Negative","Ambience": "Positive"}Here are the liked and disliked features for each aspect:"Food Quality Features": [["Pulled Duck Salad was prepared and seasoned well"]],"Service Features": [["The service was slow and inattentive"]],"Ambience Features": [["The interior is friendly and not intimidating like any other pubs", "the second floor, especially, has a cozy feel"]]}Here's how I arrived at these conclusions:* Overall sentiment: The review mentions that the place is nice for evening drinks and food but also states that it's not cost-effective. Based on this information, I classify the overall sentiment as Neutral.* Food Quality: The reviewer enjoyed the Pulled Duck Salad and thought it was prepared well, so I classify the sentiment for Food Quality as Positive.* Service: The service was slow and inattentive, so I classify the sentiment for Service as Negative.* Ambience: The interior and second floor of the pub were described as friendly and cozy, so I classify the sentiment for Ambience as Positive.I hope this helps! Let me know if you have any further questions or need more information.

# %%
print(data_4.loc[7, 'model_response'])
# Out:
#  Sure! Here's my analysis of your restaurant review:{"Overall": "Neutral","Food Quality": "Mixed","Service": "Average","Ambience": "Not Applicable"}"Food Quality Features": [["Some dishes were tasty, others just average"]],"Service Features": [["Attentive staff members"], ["Slow service"]],"Ambience Features": []}Here's my breakdown of the review:* Overall sentiment is Neutral because while some aspects were good (e.g., attentive staff), others were just average or below par (e.g., slow service, mixed food quality).* Food Quality has a Mixed sentiment due to the reviewer's comments about some dishes being tasty but others being just average.* Service had an Average sentiment because while there were attentive staff members, the service was also described as slow.* Ambience is Not Applicable since it was not mentioned in the review.I hope this helps! Let me know if you have any further questions or need additional assistance.

# %%
upd_val_1 = {
    "Overall": "Positive",
    "Food Quality": "Positive",
    "Service": "Positive",
    "Ambience": "Not Applicable",
    "Food Quality Features": [],
    "Service Features": ["excellent service"],
    "Ambience Features": []
}

upd_val_2 = {
    "Overall": "Neutral",
    "Food Quality": "Neutral",
    "Service": "Neutral",
    "Ambience": "Not Applicable",
    "Food Quality Features": ["well prepared"],
    "Service Features": ["slow and inattentive"],
    "Ambience Features": ["interior is friendly", "not intimidating"]
}

upd_val_3 = {
    "Overall": "Neutral",
    "Food Quality": "Positive",
    "Service": "Negative",
    "Ambience": "Positive",
    "Food Quality Features": ["Some tasty, others average"],
    "Service Features": ["Attentive staff", "Slow service"],
    "Ambience Features": []
}

# defining the list of indices to update
idx_list = [3,6,7]
data_4.loc[idx_list, 'model_response_parsed'] = [upd_val_1, upd_val_2, upd_val_3]

# %% [markdown]
# **Note**: The values model responses that cannot be parsed correctly by the JSON parser function may vary with execution due to the randomness associated with LLMs. Kindly update as observed when run in your system.

# %%
model_response_parsed_df_4 = pd.json_normalize(data_4['model_response_parsed'])
model_response_parsed_df_4.head()
# Out:
#     Overall Food Quality   Service        Ambience     Food Quality Features  \
# 0  Positive     Positive  Positive        Positive  [straight from the oven]
# 1  Positive     Positive   Neutral        Positive         [exquisite taste]
# 2  Positive     Positive  Positive         Neutral         [Excellent taste]
# 3  Positive     Positive  Positive  Not Applicable                        []
# 4  Positive     Positive  Positive         Neutral                [fabulous]
#
#       Service Features                              Ambience Features
# 0                   []                                             []
# 1                   []  [peaceful and the plants enhanced its beauty]
# 2      [Great service]                                             []
# 3  [excellent service]                                             []
# 4               [nice]                                             []

# %%
data_with_parsed_model_output_4 = pd.concat([data_4, model_response_parsed_df_4], axis=1)
data_with_parsed_model_output_4.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full  \
# 0  Totally in love with the Auro of the place, re...
# 1  Kailash colony is brimming with small cafes no...
# 2  Excellent taste and awesome decorum. Must visi...
# 3  I have visited at jw lough/restourant. There w...
# 4  Had a great experience in the restaurant food ...
#
#                                       model_response  \
# 0   Sure! Here's my analysis of your provided rev...
# 1   Sure! I can assist you with that. Here is my ...
# 2   Sure! I can assist you with that. Here's my a...
# 3   Sure! I can assist you with that. Here's my a...
# 4   Sure! Here's my analysis of your provided rev...
#
#                                model_response_parsed   Overall Food Quality  \
# 0  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 1  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 2  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 3  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 4  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
#
#     Service        Ambience     Food Quality Features     Service Features  \
# 0  Positive        Positive  [straight from the oven]                   []
# 1   Neutral        Positive         [exquisite taste]                   []
# 2  Positive         Neutral         [Excellent taste]      [Great service]
# 3  Positive  Not Applicable                        []  [excellent service]
# 4  Positive         Neutral                [fabulous]               [nice]
#
#                                Ambience Features
# 0                                             []
# 1  [peaceful and the plants enhanced its beauty]
# 2                                             []
# 3                                             []
# 4                                             []

# %%
final_data_4 = data_with_parsed_model_output_4.drop(['model_response','model_response_parsed'], axis=1)
final_data_4.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full   Overall Food Quality  \
# 0  Totally in love with the Auro of the place, re...  Positive     Positive
# 1  Kailash colony is brimming with small cafes no...  Positive     Positive
# 2  Excellent taste and awesome decorum. Must visi...  Positive     Positive
# 3  I have visited at jw lough/restourant. There w...  Positive     Positive
# 4  Had a great experience in the restaurant food ...  Positive     Positive
#
#     Service        Ambience     Food Quality Features     Service Features  \
# 0  Positive        Positive  [straight from the oven]                   []
# 1   Neutral        Positive         [exquisite taste]                   []
# 2  Positive         Neutral         [Excellent taste]      [Great service]
# 3  Positive  Not Applicable                        []  [excellent service]
# 4  Positive         Neutral                [fabulous]               [nice]
#
#                                Ambience Features
# 0                                             []
# 1  [peaceful and the plants enhanced its beauty]
# 2                                             []
# 3                                             []
# 4                                             []

# %%
final_data_4['Overall'].value_counts()
# Out:
# Neutral     8
# Positive    6
# Negative    6
# Name: Overall, dtype: int64

# %%
final_data_4['Food Quality'].value_counts()
# Out:
# Positive          9
# Neutral           4
# Mixed             3
# Not Applicable    2
# Negative          2
# Name: Food Quality, dtype: int64

# %%
final_data_4['Service'].value_counts()
# Out:
# Positive        8
# Negative        8
# Neutral         2
# Inconsistent    1
# Slow            1
# Name: Service, dtype: int64

# %%
final_data_4['Ambience'].value_counts()
# Out:
# Neutral           8
# Not Applicable    6
# Positive          5
# Cozy              1
# Name: Ambience, dtype: int64

# %% [markdown]
# ## 5. Identifying Overall Sentiment, Sentiment of Aspects of the Experience, Liked/Disliked Features of the Different Aspects of the Experience, and Sharing a Response (Llama)

# %%
# creating a copy of the data
data_5 = data.copy()

# %%
# defining the instructions for the model
instruction_5 = """
    You are an AI analyzing restaurant reviews. Classify the overall sentiment of the provided review into the following categories:
    - "Positive"
    - "Negative"
    - "Neutral"

    Once that is done, check for a mention of the following aspects in the review and clasify the sentiment of each aspect as positive, negative, or neutral:
    1. Food quality
    2. Service
    3. Ambience

    Once that is done, look for liked and/or disliked features mentioned against each of the above aspects in the review and extract them.

    Finally, draft a response for the customer based on the review. Start out with a thank you note and then add on to it as per the following:
    1. If the review is positive, mention that it would be great to have them again
    2. If the review is neutral, ask them for what the restaurant could have done better
    3. If the review is negative, apologive for the inconvenience and mention that we'll be looking into the points raised

    Return the output in the specified JSON format, ensuring consistency and handling missing values appropriately Ensure that all values in the JSON are formatted as strings, and each element within the lists should be enclosed in double quotes:

    {
        "Overall": "your_sentiment_prediction",
        "Food Quality": "your_sentiment_prediction",
        "Service": "your_sentiment_prediction",
        "Ambience": "your_sentiment_prediction",
        "Food Quality Features": ["liked/disliked features"],
        "Service Features": ["liked/disliked features"],
        "Ambience Features": ["liked/disliked features"],
        "Response": "your_response_to_the_customer_review",
    }

    The sentiment prediction for Overall, Food Quality, Service, and Ambience should be one of "Positive", "Negative", or "Neutral" only.
    In case one of the three aspects is not mentioned in the review, set "Not Applicable" (including quotes) in the corresponding JSON key value for the sentiment.
    In case there are no liked/disliked features for a particular aspect, assign an empty list in the corresponding JSON key value for the aspect.
    Be polite and empathetic in the response to the customer review.
    Only return the JSON, do NOT return any other text or information.
"""

# %%
data_5['model_response'] = data_5['review_full'].apply(lambda x: generate_llama_response(instruction_5, x))
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit

# %%
i = 2
print(data_5.loc[i, 'review_full'])
# Out:
# Excellent taste and awesome decorum. Must visit. Subham Barnwal had given us a great service. One of the best experience.

# %%
print(data_5.loc[i, 'model_response'])
# Out:
#  {
# "Overall": "Positive",
# "Food Quality": "Positive",
# "Service": "Positive",
# "Ambience": "Positive",
# "Food Quality Features": ["Excellent taste"],
# "Service Features": ["Great service"],
# "Ambience Features": ["Awesome decorum"],
# "Response": "Thank you for taking the time to review us! We're thrilled that you enjoyed our food quality, service and ambience. Your positive feedback is greatly appreciated and we look forward to serving you again soon!"
# }

# %%
# applying the function to the model response
data_5['model_response_parsed'] = data_5['model_response'].apply(extract_json_data)
data_5['model_response_parsed'].head()
# Out:
# 0    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 1    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 2    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 3    {'Overall': 'Positive', 'Food Quality': 'Posit...
# 4    {'Overall': 'Positive', 'Food Quality': 'Posit...
# Name: model_response_parsed, dtype: object

# %%
model_response_parsed_df_5 = pd.json_normalize(data_5['model_response_parsed'])
model_response_parsed_df_5.head()
# Out:
#     Overall Food Quality   Service  Ambience     Food Quality Features  \
# 0  Positive     Positive  Positive  Positive  [straight from the oven]
# 1  Positive     Positive   Neutral  Positive         [exquisite taste]
# 2  Positive     Positive  Positive  Positive         [Excellent taste]
# 3  Positive     Positive  Positive   Neutral             [superb food]
# 4  Positive     Positive  Positive   Neutral               [good food]
#
#         Service Features                              Ambience Features  \
# 0                     []                                             []
# 1                     []  [peaceful and the plants enhanced its beauty]
# 2        [Great service]                              [Awesome decorum]
# 3  [first class service]                                             []
# 4           [nice staff]                                             []
#
#                                             Response
# 0  Thank you for taking the time to review Fatjar...
# 1  Thank you for taking the time to review us! We...
# 2  Thank you for taking the time to review us! We...
# 3  Thank you for taking the time to review your r...
# 4  Thank you for taking the time to review your r...

# %%
data_with_parsed_model_output_5 = pd.concat([data_5, model_response_parsed_df_5], axis=1)
data_with_parsed_model_output_5.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full  \
# 0  Totally in love with the Auro of the place, re...
# 1  Kailash colony is brimming with small cafes no...
# 2  Excellent taste and awesome decorum. Must visi...
# 3  I have visited at jw lough/restourant. There w...
# 4  Had a great experience in the restaurant food ...
#
#                                       model_response  \
# 0   {\n"Overall": "Positive",\n"Food Quality": "P...
# 1   {\n"Overall": "Positive",\n"Food Quality": "P...
# 2   {\n"Overall": "Positive",\n"Food Quality": "P...
# 3   {\n"Overall": "Positive",\n"Food Quality": "P...
# 4   {\n"Overall": "Positive",\n"Food Quality": "P...
#
#                                model_response_parsed   Overall Food Quality  \
# 0  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 1  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 2  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 3  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
# 4  {'Overall': 'Positive', 'Food Quality': 'Posit...  Positive     Positive
#
#     Service  Ambience     Food Quality Features       Service Features  \
# 0  Positive  Positive  [straight from the oven]                     []
# 1   Neutral  Positive         [exquisite taste]                     []
# 2  Positive  Positive         [Excellent taste]        [Great service]
# 3  Positive   Neutral             [superb food]  [first class service]
# 4  Positive   Neutral               [good food]           [nice staff]
#
#                                Ambience Features  \
# 0                                             []
# 1  [peaceful and the plants enhanced its beauty]
# 2                              [Awesome decorum]
# 3                                             []
# 4                                             []
#
#                                             Response
# 0  Thank you for taking the time to review Fatjar...
# 1  Thank you for taking the time to review us! We...
# 2  Thank you for taking the time to review us! We...
# 3  Thank you for taking the time to review your r...
# 4  Thank you for taking the time to review your r...

# %%
final_data_5 = data_with_parsed_model_output_5.drop(['model_response','model_response_parsed'], axis=1)
final_data_5.head()
# Out:
#   restaurant_ID  rating_review  \
# 0        FLV202              5
# 1        SAV303              5
# 2        YUM789              5
# 3        TST101              5
# 4        EAT456              5
#
#                                          review_full   Overall Food Quality  \
# 0  Totally in love with the Auro of the place, re...  Positive     Positive
# 1  Kailash colony is brimming with small cafes no...  Positive     Positive
# 2  Excellent taste and awesome decorum. Must visi...  Positive     Positive
# 3  I have visited at jw lough/restourant. There w...  Positive     Positive
# 4  Had a great experience in the restaurant food ...  Positive     Positive
#
#     Service  Ambience     Food Quality Features       Service Features  \
# 0  Positive  Positive  [straight from the oven]                     []
# 1   Neutral  Positive         [exquisite taste]                     []
# 2  Positive  Positive         [Excellent taste]        [Great service]
# 3  Positive   Neutral             [superb food]  [first class service]
# 4  Positive   Neutral               [good food]           [nice staff]
#
#                                Ambience Features  \
# 0                                             []
# 1  [peaceful and the plants enhanced its beauty]
# 2                              [Awesome decorum]
# 3                                             []
# 4                                             []
#
#                                             Response
# 0  Thank you for taking the time to review Fatjar...
# 1  Thank you for taking the time to review us! We...
# 2  Thank you for taking the time to review us! We...
# 3  Thank you for taking the time to review your r...
# 4  Thank you for taking the time to review your r...

# %%
final_data_5['Overall'].value_counts()
# Out:
# Neutral     10
# Positive     6
# Negative     4
# Name: Overall, dtype: int64

# %%
final_data_5['Food Quality'].value_counts()
# Out:
# Positive          10
# Neutral            5
# Negative           3
# Mixed              1
# Not Applicable     1
# Name: Food Quality, dtype: int64

# %%
final_data_5['Service'].value_counts()
# Out:
# Positive    9
# Negative    9
# Neutral     1
# Slow        1
# Name: Service, dtype: int64

# %%
final_data_5['Ambience'].value_counts()
# Out:
# Neutral           14
# Positive           5
# Not Applicable     1
# Name: Ambience, dtype: int64

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - We used an LLM to do multiple tasks, one stage at a time
#     1. We first identified the overall sentiment of the review using the LLM
#     2. We then identified the overall sentiment of the review and got the output in a structured format from the LLM for ease-of-access
#     3. Next, we identified the overall sentiment of the review as well as sentiment of specific aspects of the experience
#     4. Next, in addition to the overall sentiment of the review as well as sentiment of specific aspects of the experience, we also identified the liked/disliked features of the different aspects of the experience
#     5. Finally, in addition to all the above, we also got a response we can share with the customer based on their review
#
# - One can manually label the data (overall sentiment and sentiments of different aspects) and then compare the model's output with the same to get a quantitative measure of the models performance.
#
# - To try and improve the model performance, one can try the following:
#     1. Update the prompt
#     2. Update the model parameters (`temparature`, `top_p`, ...)

# %% [markdown]
# ___
